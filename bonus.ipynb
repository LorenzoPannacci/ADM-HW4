# %% [markdown]
# Notebook by:
#
# * Lorenzo Pannacci - 1948926
# * Francesco Lazzari - 1917922
# * Stefano Rinaldi - 1945551
# * Emmanuele De Lucia - 2099678

# %% [markdown]
# ## Startup

# %%
######################
# LIBRARIES DOWNLOAD #
######################

install_packages = False
if install_packages:
    # %pip install numpy pandas pyspark scipy matplotlib seaborn prince yellowbrick

# %%
####################
# LIBRARIES IMPORT #
####################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark import SparkContext
from scipy.spatial.distance import cdist
from scipy.stats import chi2_contingency
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs
from sklearn.cluster import MeanShift
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs
from prince import FAMD, MCA, PCA
from yellowbrick.cluster import KElbowVisualizer
from operator import itemgetter
from itertools import combinations
from collections import defaultdict, Counter

import random
random.seed(42)

import warnings
warnings.filterwarnings("ignore")

import os
# set spark environment
os.environ['PYSPARK_PYTHON'] = r"D:\File\Anaconda\pythonw.exe"
os.environ['PYSPARK_DRIVER_PYTHON'] = r"D:\File\Anaconda\pythonw.exe"

# os.environ['PYSPARK_PYTHON'] = r"D:\Programs\Anaconda\pythonw.exe"
# os.environ['PYSPARK_DRIVER_PYTHON'] = r"D:\Programs\Anaconda\pythonw.exe"

# %%
#####################
# GLOBAL PARAMETERS #
#####################

dataset_path = r"vodclickstream_uk_movies_03.csv"

# %% [markdown]
# ## 0. Data exploration and clean-up

# %% [markdown]
# ---
#
# Before starting with the homework requests we explore our data to have an idea of the enviroment we will be working on, understanding what the dataset is composed of, what's the meaning of each and every feature and if necessary clean the data and to convert it in a more usable form. Since the dataset is light (around 72 Mb) we won't need to worry about dividing it into chunks.
#
# From the Kaggle webpage of the dataset (https://www.kaggle.com/datasets/vodclickstream/netflix-audience-behaviour-uk-movies) we gather some preliminary informations: the dataset contains behavioral informations of Netflix users from January 2017 to June 2019. It particular it contains only informations of users residents in the UK, that used the web application of Netflix (meaning only desktop and laptop activity) and only of those users who opted in for tracking.
#
# The dataset documents instances of clicks on a URL for a Netflix movie and the time spent on that page, while giving also some informations about the movies themselves.
#
# ---

# %%
# load the dataset from the .csv file to a pandas dataframe
original_dataset = pd.read_csv(dataset_path)
original_dataset
# Out:
#         Unnamed: 0             datetime  duration  \
# 0            58773  2017-01-01 01:15:09       0.0
# 1            58774  2017-01-01 13:56:02       0.0
# 2            58775  2017-01-01 15:17:47   10530.0
# 3            58776  2017-01-01 16:04:13      49.0
# 4            58777  2017-01-01 19:16:37       0.0
# ...            ...                  ...       ...
# 671731      730504  2019-06-30 21:37:08     851.0
# 671732      730505  2019-06-30 21:49:34   91157.0
# 671733      730506  2019-06-30 22:00:44       0.0
# 671734      730507  2019-06-30 22:04:23       0.0
# 671735      730508  2019-06-30 22:35:24       0.0
#
#                                             title  \
# 0              Angus, Thongs and Perfect Snogging
# 1                    The Curse of Sleeping Beauty
# 2                               London Has Fallen
# 3                                        Vendetta
# 4                 The SpongeBob SquarePants Movie
# ...                                           ...
# ...

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671736 entries, 0 to 671735
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    671736 non-null  int64
#  1   datetime      671736 non-null  object
#  2   duration      671736 non-null  float64
#  3   title         671736 non-null  object
#  4   genres        671736 non-null  object
#  5   release_date  671736 non-null  object
#  6   movie_id      671736 non-null  object
#  7   user_id       671736 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 41.0+ MB

# %% [markdown]
# ---
#
# The first thing we notice is the presence of a column called `Unnamed: 0` that has an incremental value. This column works as an "iteraction ID", we decided to discard it and use our own index, that starts from 0:
#
# ---

# %%
original_dataset.drop('Unnamed: 0', axis = 1, inplace = True)
original_dataset
# Out:
#                    datetime  duration  \
# 0       2017-01-01 01:15:09       0.0
# 1       2017-01-01 13:56:02       0.0
# 2       2017-01-01 15:17:47   10530.0
# 3       2017-01-01 16:04:13      49.0
# 4       2017-01-01 19:16:37       0.0
# ...                     ...       ...
# 671731  2019-06-30 21:37:08     851.0
# 671732  2019-06-30 21:49:34   91157.0
# 671733  2019-06-30 22:00:44       0.0
# 671734  2019-06-30 22:04:23       0.0
# 671735  2019-06-30 22:35:24       0.0
#
#                                             title  \
# 0              Angus, Thongs and Perfect Snogging
# 1                    The Curse of Sleeping Beauty
# 2                               London Has Fallen
# 3                                        Vendetta
# 4                 The SpongeBob SquarePants Movie
# ...                                           ...
# 671731        Oprah Presents When They See Us Now
# 671732                               HALO Legends
# ...

# %% [markdown]
# ---
#
# It will be useful to convert both the the `datetime` and the `release_date` columns from a string to actual datetime format. We notice that some entries of `release_date` have value `NOT AVAILABLE`, we will have to convert them to NaT (Not a Time).
#
# ---

# %%
original_dataset.datetime = pd.to_datetime(original_dataset.datetime, errors='coerce')
original_dataset.release_date = pd.to_datetime(original_dataset.release_date, errors='coerce')
original_dataset
# Out:
#                   datetime  duration  \
# 0      2017-01-01 01:15:09       0.0
# 1      2017-01-01 13:56:02       0.0
# 2      2017-01-01 15:17:47   10530.0
# 3      2017-01-01 16:04:13      49.0
# 4      2017-01-01 19:16:37       0.0
# ...                    ...       ...
# 671731 2019-06-30 21:37:08     851.0
# 671732 2019-06-30 21:49:34   91157.0
# 671733 2019-06-30 22:00:44       0.0
# 671734 2019-06-30 22:04:23       0.0
# 671735 2019-06-30 22:35:24       0.0
#
#                                             title  \
# 0              Angus, Thongs and Perfect Snogging
# 1                    The Curse of Sleeping Beauty
# 2                               London Has Fallen
# 3                                        Vendetta
# 4                 The SpongeBob SquarePants Movie
# ...                                           ...
# 671731        Oprah Presents When They See Us Now
# 671732                               HALO Legends
# 671733                                Pacific Rim
# ...

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671736 entries, 0 to 671735
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datetime      671736 non-null  datetime64[ns]
#  1   duration      671736 non-null  float64
#  2   title         671736 non-null  object
#  3   genres        671736 non-null  object
#  4   release_date  641432 non-null  datetime64[ns]
#  5   movie_id      671736 non-null  object
#  6   user_id       671736 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 35.9+ MB

# %% [markdown]
# ---
#
# The Kaggle page of the dataset (https://www.kaggle.com/datasets/vodclickstream/netflix-audience-behaviour-uk-movies) give us informations about the `duration` column:
#
# **" 'duration' shows how long it was (in seconds) until that user clicked on another URL. A watch time of zero seconds means they visited the page but instantly clicked away."**
#
# It is already a float, we don't need to treat it any further.
#
# We can check the consistency of the dataset by checking if the same movie (i.e. all the entries with same `movie_id`) have the same characteristics (i.e. same `title`, `genres` and `release date`):
#
# ---

# %%
# iterate trough every movie
for movie_id, group_data in original_dataset.groupby('movie_id'):
    
    # check if there is more than a title for the same movie
    if group_data.title.unique().shape[0] != 1:
        print("Movie", movie_id, "has more than a title!")

    # check if there is more than a genre list for the same movie
    if group_data.genres.unique().shape[0] != 1:
        print("Movie", movie_id, "has conflicting genres!")

    # check if there is more than a release date for the same movie
    if group_data.release_date.unique().shape[0] != 1:
        print("Movie", movie_id, "has conflicting release dates!")

# %% [markdown]
# ---
#
# Since the `genres` column is a string we have to convert it to a list to treat it more easily in further analysis.
#
# ---

# %%
original_dataset
# Out:
#                   datetime  duration  \
# 0      2017-01-01 01:15:09       0.0
# 1      2017-01-01 13:56:02       0.0
# 2      2017-01-01 15:17:47   10530.0
# 3      2017-01-01 16:04:13      49.0
# 4      2017-01-01 19:16:37       0.0
# ...                    ...       ...
# 671731 2019-06-30 21:37:08     851.0
# 671732 2019-06-30 21:49:34   91157.0
# 671733 2019-06-30 22:00:44       0.0
# 671734 2019-06-30 22:04:23       0.0
# 671735 2019-06-30 22:35:24       0.0
#
#                                             title  \
# 0              Angus, Thongs and Perfect Snogging
# 1                    The Curse of Sleeping Beauty
# 2                               London Has Fallen
# 3                                        Vendetta
# 4                 The SpongeBob SquarePants Movie
# ...                                           ...
# 671731        Oprah Presents When They See Us Now
# 671732                               HALO Legends
# 671733                                Pacific Rim
# ...

# %%
original_dataset.genres = original_dataset.genres.apply(lambda row: row.split(', '))
original_dataset
# Out:
#                   datetime  duration  \
# 0      2017-01-01 01:15:09       0.0
# 1      2017-01-01 13:56:02       0.0
# 2      2017-01-01 15:17:47   10530.0
# 3      2017-01-01 16:04:13      49.0
# 4      2017-01-01 19:16:37       0.0
# ...                    ...       ...
# 671731 2019-06-30 21:37:08     851.0
# 671732 2019-06-30 21:49:34   91157.0
# 671733 2019-06-30 22:00:44       0.0
# 671734 2019-06-30 22:04:23       0.0
# 671735 2019-06-30 22:35:24       0.0
#
#                                             title  \
# 0              Angus, Thongs and Perfect Snogging
# 1                    The Curse of Sleeping Beauty
# 2                               London Has Fallen
# 3                                        Vendetta
# 4                 The SpongeBob SquarePants Movie
# ...                                           ...
# 671731        Oprah Presents When They See Us Now
# 671732                               HALO Legends
# 671733                                Pacific Rim
# ...

# %% [markdown]
# ## 1. Recommendation sytem

# %% [markdown]
# Implementing a recommendation system is critical for businesses and digital platforms that want to thrive in today's competitive environment. These systems use data-driven personalization to tailor content, products, and services to individual user preferences. The latter improves user engagement, satisfaction, retention, and revenue through increased sales and cross-selling opportunities. In this section, you will attempt to implement a recommendation system by identifying similar users' preferences and recommending movies they watch to the study user.
#
# To be more specific, you will implement your version of the [**LSH algorithm**](https://www.learndatasci.com/tutorials/building-recommendation-engine-locality-sensitive-hashing-lsh-python/), which will take as input the user's preferred genre of movies, find the most similar users to this user, and recommend the most watched movies by those who are more similar to the user.
#
# __Data__: The data you will be working with can be found [here](https://www.kaggle.com/datasets/vodclickstream/netflix-audience-behaviour-uk-movies).
#
# Looking at the data, you can see that there is data available for each user for the movies the user <ins>clicked on</ins>. Gather the __title and genre__ of the __maximum top 10 movies__ that each user clicked on regarding the __number of clicks__.

# %% [markdown]
# ---
#
# The aim is to find the top 10 film with most clicks for each user.
#
# <code style="background:red;color:black"> Starting from the cleaned dataset we are going to:</code>
#
# 1. Group by user and movie <br>
# 2. Count the clicks <br>
# 3. Sort the data by click count for each user.<br>
# 4. Extract the top 10 movies for each user and take title and genre.<br>
#
# ---

# %%
# create a new dataframe with the information I need
users = original_dataset[["genres", "user_id","title"]]

# group user and movie and count the click
user_movie_counts = users.groupby(['user_id', 'title']).size().reset_index(name='click_count')

# sort them
user_movie_counts = user_movie_counts.sort_values(by=['user_id', 'click_count'], ascending=[True, False])

# take the top 10 movies for each user
user_movie_counts = user_movie_counts.groupby('user_id').head(10)

# return a new dataframe with the top 10 movies for each user
# we keep as informations the user, the title and the genre of the movie as well as the click count
# other columns are not requested and will be removed

result = pd.merge(user_movie_counts, users[['user_id', 'title', 'genres']], on=['user_id', 'title'], how='left')

# as list are unhashable we convert genres back to string
result['genres'] = result['genres'].apply(lambda x: ', '.join(map(str, x)))

# finally we have to remove duplicates
# this is needed as the previous operations gave us the right answer, but
# every row is repeated for each click count it has, so for example if a
# movie has 9 clicks, it creates 9 times that rows
result.drop_duplicates(inplace = True)

result
# Out:
#            user_id              title  click_count  \
# 0       00004e2862           Hannibal            1
# 1       000052a0a0             Looper            9
# 10      000052a0a0            Frailty            3
# 13      000052a0a0            Jumanji            3
# 16      000052a0a0      Resident Evil            2
# ...            ...                ...          ...
# 613980  fffeac83be        To the Bone            1
# 613981  fffeac83be         True Story            1
# 613982  ffff2c5f9e  Forks Over Knives            1
# 613983  ffff2c5f9e           Hot Fuzz            1
# 613984  ffffd36adf   Dead Man Walking            1
#
#                                     genres
# 0                   Crime, Drama, Thriller
# 1          Action, Drama, Sci-Fi, Thriller
# 10                  Crime, Drama, Thriller
# 13      Adventure, Comedy, Family, Fantasy
# 16                  Action, Horror, Sci-Fi
# ...                                    ...
# ...

# %% [markdown]
# ---
#
# The following code block is an example to test the new dataset. You can retrieve the result for a specific user by changing the input with a desidered "user_id".
#
# ---

# %%
# you can change the input with a desidered user_id
input_user_id = "1df8e21154"

result[result['user_id'] == input_user_id]
# Out:
#           user_id                       title  click_count  \
# 70879  1df8e21154                     Beastly            5
# 70884  1df8e21154                     Titanic            4
# 70888  1df8e21154                    Addicted            3
# 70891  1df8e21154                 Match Point            3
# 70894  1df8e21154     My Last Day without You            3
# 70897  1df8e21154              The Red Thread            3
# 70900  1df8e21154                 After Earth            2
# 70902  1df8e21154                   Boomerang            2
# 70904  1df8e21154  Diary of a Mad Black Woman            2
# 70906  1df8e21154                  Lift Me Up            2
#
#                           genres
# 70879    Drama, Fantasy, Romance
# 70884             Drama, Romance
# 70888            Drama, Thriller
# 70891   Drama, Romance, Thriller
# 70894     Comedy, Drama, Romance
# 70897             Drama, Romance
# 70900  Action, Adventure, Sci-Fi
# 70902     Comedy, Drama, Romance
# ...

# %% [markdown]
# ---
#
# <code style="background:orange;color:black">**Comment:**</code> <br>
#
# Here we can see the result for a specific user (and before also for all users together). Result is ordered by click count. In this case, we are taking into consideration all clicks and films and users. We decided that even if a click has a duration of 0 it is taken into consideration as the user showed interest to the movie and so is useful for both building the next hashing function and for counting the film with most clicks.
#
# ---

# %% [markdown]
# ### 1.2 Minhash Signatures

# %% [markdown]
# Using the movie genre and user_ids, try to implement your min-hash signatures so that users with similar interests in a genre appear in the same bucket.
#
# __Important note:__ You must write your minhash function from scratch.  You are not permitted to use any already implemented hash functions.  Read the class materials and, if necessary, conduct an internet search.  The description of hash functions in the [book](http://infolab.stanford.edu/~ullman/mmds/ch3n.pdf) may be helpful as a reference.

# %% [markdown]
# ---
#
# Here we group users together into buckets based on the film genres in such a way that users in the same bucket have similar movie interests.
#
# <code style="background:red;color:black"> This is what we are going to do step by step:</code>
#
# **0. Group users and genres**<br>
# We create a dictionary in which the keys are the *user_id* and the values the *genres* associated to each user.<br>
#
# **1. Create a matrix with genres for each user** <br>
# We create a matrix in which we assign *1* if the user has ever seen that genre and *0* if the user has not.<br>
#
# **2. Compute signatures for each user** <br>
# Given the previously computed matrix we first create some random hash functions and then compute the signature for each user.<br>
#
# **3. Bucketing**<br>
# Now that we have the signatures we can divide users into buckets
#
# ---

# %%
# 0)
# we create a 2 columns dataframe: one with the users_id and one with the genres, each row will only have one genre
# this will be needed for creating a dictionary with users as keys and genres as values

genres_with_user = original_dataset[["user_id", "genres"]]
genres_with_user = genres_with_user.explode('genres').reset_index(drop = True)
genres_with_user
# Out:
#             user_id       genres
# 0        1dea19f6fe       Comedy
# 1        1dea19f6fe        Drama
# 2        1dea19f6fe      Romance
# 3        544dcbc510      Fantasy
# 4        544dcbc510       Horror
# ...             ...          ...
# 2002594  4a14a2cd5a       Sci-Fi
# 2002595  0b8163ea4b  Documentary
# 2002596  0b8163ea4b        Music
# 2002597  5e5755d816       Comedy
# 2002598  5e5755d816        Drama
#
# [2002599 rows x 2 columns]

# %%
# create a dictionary where we have as keys the user_id and as values all genres related to it

user_genres_dict = {}

# iterate over dataframe
for index, row in genres_with_user.iterrows():
    user_id = row['user_id']
    genre = row['genres']

    # if user_id already exist, append 
    if user_id in user_genres_dict:
        user_genres_dict[user_id].append(genre)

    # otherwise, create the key
    else:
        user_genres_dict[user_id] = [genre]

# then we convert into a dataframe (it will be necessary later)
user_genres_df = pd.DataFrame(list(user_genres_dict.items()), columns=['user_id', 'genres'])
user_genres_df
# Out:
#            user_id                                             genres
# 0       1dea19f6fe                           [Comedy, Drama, Romance]
# 1       544dcbc510  [Fantasy, Horror, Mystery, Thriller, Comedy, R...
# 2       7cbcc791bf  [Action, Thriller, Action, Thriller, Action, C...
# 3       ebf43c36b6  [Action, Drama, Action, Drama, Animation, Adve...
# 4       a57c992287  [Animation, Action, Adventure, Comedy, Family,...
# ...            ...                                                ...
# 161913  45414be0ec                                  [Comedy, Romance]
# 161914  783ec67e84                          [Biography, Drama, Sport]
# 161915  89c715f3a4  [Animation, Adventure, Comedy, Family, Fantasy...
# 161916  9207e1499b                          [Biography, Crime, Drama]
# 161917  57501964fd                                        [Talk-Show]
#
# [161918 rows x 2 columns]

# %%
# 1) create the matrix 

# retrieve all unique film genres
unique_genres = set()
original_dataset["genres"].apply(lambda row: [unique_genres.add(value) for value in row])
unique_genres = sorted(list(unique_genres))

# create my matrix: columns are genres and the index is user_id
users_genres_matrix = pd.DataFrame(0, index=original_dataset["user_id"].unique(), columns = unique_genres)

# put 1 if the user has that genre, put 0 if not
for user_id, genres in user_genres_dict.items():
    for genre in genres:
        if genre in unique_genres:
            users_genres_matrix.loc[user_id, genre] = 1

users_genres_matrix.head()
# Out:
#             Action  Adventure  Animation  Biography  Comedy  Crime  \
# 1dea19f6fe       0          0          0          0       1      0
# 544dcbc510       0          1          0          0       1      0
# 7cbcc791bf       1          1          1          0       1      1
# ebf43c36b6       1          1          1          1       1      1
# a57c992287       1          1          1          1       1      1
#
#             Documentary  Drama  Family  Fantasy  ...  News  Reality-TV  \
# 1dea19f6fe            0      1       0        0  ...     0           0
# 544dcbc510            0      1       0        1  ...     0           0
# 7cbcc791bf            0      0       1        1  ...     0           0
# ebf43c36b6            0      1       1        1  ...     0           0
# a57c992287            1      1       1        1  ...     0           0
#
#             Romance  Sci-Fi  Short  Sport  Talk-Show  Thriller  War  Western
# ...

# %%
# 2) compute signature for all users

# we create the hash function
# we give a number of choice and create that number of functions, the coefficient x and y are different every time
# the equation is fixed but the parameters are changede randomly

def generate_hash(n_hashes):
    hash_functions = []

    for _ in range(n_hashes):
        x = random.randint(1, 100)
        y = random.randint(0, 100)
        hash_functions.append((x, y))

    return hash_functions

# calculate signature
def calculate_signature(user_preferences, n_hashes, n_genres, list_functions):
    signature = [float('inf')] * n_hashes

    # for every element of my matrix (which is actually a dataframe)
    # for every genre index and the binary encoding (0, 1)
    for index, present in enumerate(user_preferences):

        # for each genre execute the hash functions
        for k, hash_function in enumerate(list_functions):
            x, y = hash_function
            hash_value = (x * index * present + y) % n_genres
            # retain only the minimun
            signature[k] = min(signature[k], hash_value)

    # so here we will have the minimum
    return signature

# %%
#############################################
# THE VARIABLES WE SELECTED FOR THE HASHING #
#############################################
# the more the n_hashes, the better we expect the results,
# but the execution will require more time

genres = list(unique_genres)
n_hashes = 15
n_genres = len(genres)
list_functions = generate_hash(n_hashes)

# %%
# dictionary that will store the signatures for each user
signatures = {}

#I calculare the signature for each user in the matrix (which is a dataframe actually)
for user_id, user_preferences in users_genres_matrix.iterrows():
    signature = calculate_signature(user_preferences, n_hashes, n_genres, list_functions)
    signatures[user_id] = signature

# %%
#3) divide users into buckets basing on their signature

def bucketing(signatures, n_hashes, n_bands):
    # number of rows per band
    n_rows = n_hashes // n_bands

    # dictionary that will store the buckets
    buckets = defaultdict(list)

    # for each user:
    for user_id, signature in signatures.items():
        for band_index in range(n_bands):
            # calculates the start and end indices for the current band.
            start = band_index * n_rows
            end = (band_index + 1) * n_rows

            # extract the band from the minhash signature and convert it to a tuple
            band = tuple(signature[start:end])

            # append the user to the corresponding bucket based on the value.
            buckets[band].append(user_id)

    return buckets

n_bands= 6
buckets = bucketing(signatures, n_hashes, n_bands)

# %% [markdown]
# ### 1.3 Locality-Sensitive Hashing (LSH)

# %% [markdown]
# Now that your buckets are ready, it's time to ask a few queries. We will provide you with some user_ids and ask you to recommend at __most five movies__ to the user to watch based on the movies clicked by similar users.
#
# To recommend at most five movies given a user_id, use the following procedure:
#
# 1. Identify the <ins>two most similar</ins> users to this user.
# 2. If these two users have any movies __in common__, recommend those movies based on the total number of clicks by these users.
# 3. If there are __no more common__ movies, try to propose the most clicked movies by the __most similar user first__, followed by the other user.
#
# __Note:__ At the end of the process, we expect to see at most five movies recommended to the user.
#
# __Example:__ assume you've identified user __A__ and __B__ as the most similar users to a single user, and we have the following records on these users:
#
# - User A with 80% similarity
# - User B with 50% similarity
#
# |user|movie title|#clicks|
# |---|---|---|
# |A|Wild Child|20|
# |A|Innocence|10|
# |A|Coin Heist|2|
# |B|Innocence|30|
# |B|Coin Heist|15|
# |B|Before I Fall|30|
# |B|Beyond Skyline|8|
# |B|The Amazing Spider-Man|5|
#
# - __Recommended movies__ in order:
#     - Innocence
#     - Coin Heist
#     - Wild Child
#     - Before I Fall
#     - Beyond Skyline

# %% [markdown]
# ---
#
# <code style="background:red;color:black"> This is what we are going to do step by step:</code> <br>
#
# **1. Input the user** <br>
# Input the user to which you wish to suggest 5 films. <br>
#
# **2. Identify the similar users** <br>
# Given the inputted user we want to find all other users that share with it the same bucket(s) as they must share a common sense of genre film. For the users we find and count in how many buckets they appear that are in common with the selected user. The more buckets they share, the more probable is that they are very similar.<br>
#
# **3. Select the users** <br>
# From the proposition of similar users we created from the previous step we now compute similarity real similarity and take the top 2 users. They will be used for suggesting films.
#
# **4. Suggest common films** <br>
# If these two users have any movies in common, recommend those movies in order based on the total number of clicks by these users. <br>
#
# **5. Suggest other films** <br>
# If there are no common movies or there are less than 5 common movies, propose the most clicked movies by the most similar user first, followed by the other user. <br>
#
# ---

# %%
#1)
# INPUT HERE THE USER TO WHICH YOU WANT TO FIND THE MOST SIMILAR USERS (and therefore suggest to them 5 films)

user_id_input = "7cbcc791bf"

# %%
#2) fund the similar users 

# the idea is that given a user we count occurrences in the same buckets of the other users
# if our input user and the other users appears into a lot of common buckets, it is very likely that they have same interests
# the output is a list sorted in descending order of occurrences

def similar_users(user_id, n_users=10):
    # make a list with all users into the buckets in which the input user_id appears
    user_buckets = [bucket for bucket in buckets.values() if user_id in bucket]
    all_users = [user for bucket in user_buckets for user in bucket if user != user_id]

    # count occurrences of users
    user_occurrences = Counter(all_users)

    # sort
    sorted_user_occurrences = user_occurrences.most_common(n_users)
    
    return sorted_user_occurrences

most_similar_users = similar_users(user_id_input)

# %%
#3) select users by similarity 

# given the users we received from the previous filtering we compute on them
# jaccard similarity and sort them
# then we take the 2 users with the highest score

def calculate_jaccard_similarity(user1_genres, user2_genres):
    #jaccard similarity
    intersection = len(set(user1_genres) & set(user2_genres))
    union = len(set(user1_genres).union(user2_genres))
    return intersection / union

input_user_genres = user_genres_df[user_genres_df['user_id'] == user_id_input]['genres'].iloc[0]

# store the similarity result
similarities = []

for similar_user_id, _ in most_similar_users:
    similar_user_genres = user_genres_df[user_genres_df['user_id'] == similar_user_id]['genres'].iloc[0]
    
    jaccard_similarity = calculate_jaccard_similarity(input_user_genres, similar_user_genres)
    
    similarities.append({'user_id': similar_user_id, 'similarity': jaccard_similarity})

similarities_df = pd.DataFrame(similarities)
similarities_df = similarities_df.sort_values("similarity", ascending= False)
print(similarities_df)

# take the top 2 users
users = similarities_df.user_id.head(2)

user_1 =  users.iloc[0]
user_2 =  users.iloc[1]
# Out:
#       user_id  similarity
# 3  b8a277e68b    1.000000
# 6  a79ae92d67    0.900000
# 0  ed9688f061    0.888889
# 4  fa875e48c6    0.888889
# 9  1574d61ab3    0.888889
# 1  3d9695f224    0.800000
# 8  fb3adbb086    0.800000
# 5  9c7b1d9bc2    0.700000
# 7  c42cd4b3b2    0.700000
# 2  fbc93b4545    0.384615

# %%
# 4) if these two users have any movies in common, recommend those movies with an order based on the total number of clicks by these users

# extract common movies

# filter data for each user
user1_movies = user_movie_counts[user_movie_counts['user_id'] == user_1]
user2_movies = user_movie_counts[user_movie_counts['user_id'] == user_2]

# merge the dataframes such that I have all the movies together
merged_users = pd.concat([user1_movies, user2_movies])

# we suggest all movies that are in common and we order them by clicks count

user_groups = merged_users.groupby('user_id')['title'].apply(set)

# find the common titles between the two users
common_titles = set.intersection(user_groups.iloc[0], user_groups.iloc[1])

common_df = merged_users[merged_users['title'].isin(common_titles)].copy()

# count clicks for each film
common_df['sum_click_count'] = common_df.groupby('title')['click_count'].transform('sum')

# sort by the sum of cliks
sorted_common_df = common_df.sort_values(by='sum_click_count', ascending=False)

# films in common between the two users, drop dublicates
sorted_common_df = sorted_common_df.drop_duplicates(subset='title')
sorted_common_df = sorted_common_df[["title","sum_click_count"]]
sorted_common_df
# Out:
#                       title  sum_click_count
# 360054              Hancock                4
# 360057  Shrek Forever After                3

# %%
# if the common films are 5, we are done
# if they are less than 5, we suggest the remaining ones from the user by greatest similarity
# if the user with greatest similarity has no more other films we will pass to the second user
# EX: if the common films are 3, I will suggest only 2 films from the user with greatest similarity / the second user

# check if it has more than 5 rows, if it is the case, suggest the first 5
# if it is not the case, use following code

value = True
key = sorted_common_df.shape[0]


if sorted_common_df.shape[0] >= 5:
    value = True
    print(sorted_common_df['title'].head(5).to_list())
else:
    value = False

# %%
# 6) suggests other films
# if there are less than 5 films, then suggest others in base of the user with the most similarity:


# we create a new dataframe with the films of the two users, but without the one(s) in common
final = 5
sub_key = final - key

common_titles = set(merged_users['title'].value_counts()[merged_users['title'].value_counts() > 1].index)

# remove rows with common titles
filtered_df = merged_users[merged_users['title'].isin(common_titles) == False]

new_df = filtered_df.head(sub_key)

# first I have the common films, then we have the only-one-user films
recomended_films = pd.concat([sorted_common_df, new_df])

# %%
# since they are ordered, we just take the first 5 for the result
# this the final result.
print(recomended_films['title'].head(5).to_list())
# Out:
# ['Hancock', 'Shrek Forever After', 'Shrek', 'Austin Powers in Goldmember', 'Drive Angry']

# %% [markdown]
# ---
#
# We want to check if the computed proposal is correct. To do that we check the movie entries of the selected user and the genres list of the reccomended movies.
#
# ---

# %%
original_dataset[original_dataset["user_id"] == user_id_input]
# Out:
#                 datetime  duration              title  \
# 2    2017-01-01 15:17:47   10530.0  London Has Fallen
# 33   2017-01-01 18:13:17    3600.0  London Has Fallen
# 123  2017-01-01 20:13:06       0.0           Survivor
# 975  2017-01-02 00:26:14    3816.0  London Has Fallen
# 1018 2017-01-02 01:29:50       0.0      The Interview
# 1818 2017-01-04 19:01:15    7366.0            Shrek 2
#
#                                                  genres release_date  \
# 2                                    [Action, Thriller]   2016-03-04
# 33                                   [Action, Thriller]   2016-03-04
# 123                           [Action, Crime, Thriller]   2015-05-29
# 975                                  [Action, Thriller]   2016-03-04
# 1018                        [Action, Adventure, Comedy]   2014-12-24
# 1818  [Animation, Adventure, Comedy, Family, Fantasy...   2004-05-19
#
#         movie_id     user_id
# 2     f77e500e7a  7cbcc791bf
# 33    f77e500e7a  7cbcc791bf
# ...

# %%
print("The inputted user_id is:")
print(user_id_input)
print("\nThe user", user_id_input, "has watched the following movies:")
print(list(original_dataset[original_dataset["user_id"] == user_id_input]["title"].unique()))

print("\nThe genre preferences of user", user_id_input, " are:")
print(dict(original_dataset[original_dataset["user_id"] == user_id_input].explode("genres")["genres"].value_counts()))

print("\n The recommended movies are:")
print(recomended_films['title'].head(5).to_list())

for title in recomended_films['title'].head(5).to_list():
    print("\nGenres of movie", title, ":")
    print(original_dataset[original_dataset["title"] == title]["genres"].head(1).item())
# Out:
# The inputted user_id is:
# 7cbcc791bf
#
# The user 7cbcc791bf has watched the following movies:
# ['London Has Fallen', 'Survivor', 'The Interview', 'Shrek 2']
#
# The genre preferences of user 7cbcc791bf  are:
# {'Action': 5, 'Thriller': 4, 'Adventure': 2, 'Comedy': 2, 'Crime': 1, 'Animation': 1, 'Family': 1, 'Fantasy': 1, 'Romance': 1}
#
#  The recommended movies are:
# ['Hancock', 'Shrek Forever After', 'Shrek', 'Austin Powers in Goldmember', 'Drive Angry']
#
# Genres of movie Hancock :
# ['Action', 'Fantasy']
#
# Genres of movie Shrek Forever After :
# ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance']
#
# Genres of movie Shrek :
# ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy']
#
# Genres of movie Austin Powers in Goldmember :
# ['Action', 'Adventure', 'Comedy', 'Crime']
#
# Genres of movie Drive Angry :
# ['Action', 'Fantasy', 'Thriller']

# %% [markdown]
# ---
#
# We are satisfied with the results, as the genres of every suggested movie seems to be correlated with the preferences of the user. About this example is particularly interesting to see that the movie "Shrek 2" had a particular genre combination unusual for the user but thanks to that specificity of the combination the algorithm was able to put movies from the same series (as "Shrek" and "Shrek Forever After") in the suggestions.
#
# ---
#
# <code style="background:orange;color:black">**Comment**</code>:
#
# As we can see, the function works correctly. However there are some point that needs to be made. With proposal algorithm we created we are suggesting the films that may be liked by a user, but this type of LSH is not taking into considerations repetitions: if for example a user has sees 11 movies, 10 of which are "Comedy" and only 1 is "Drama", LSH will count "Comedy" and "Drama" as equals and it will insert 1 in the matrix, whereas the user has a clearly a greater interest into the Comedy genre. In order to build a better experience for the user, the function should take into account this and LSH may not be the right function for performing that.
#
# <code style="background:orange;color:black">**Note**</code>:
#
# The dataset was used in its entirity and not only the top 10 films for each user because we want to build a recomentation system that takes into consideration all films seen by the user and not only the top 10 in order to build the best experience for the user. In the case we want to use only the top 10 movies, it is just necessary to take to other dataset above instead of the current one.
#
# ---

# %% [markdown]
# ## 2. Grouping Users together!

# %% [markdown]
# Now, we will deal with clustering algorithms that will provide groups of Netflix users that are similar among them.
#
# To solve this task, you must accomplish the following stages:

# %% [markdown]
# ### 2.1 Getting your data + feature engineering

# %% [markdown]
# 1)  Access to the data found in [this dataset](https://www.kaggle.com/datasets/vodclickstream/netflix-audience-behaviour-uk-movies)
#
# 2)  Sometimes, the features (variables, fields) are not given in a dataset but can be created from it; this is known as *feature engineering*. For example, the original dataset has several clicks done by the same user, so grouping data by user_id will allow you to create new features **for each** user:
#
#     a)  Favorite genre (i.e., the genre on which the user spent the most time)
#
#     b)  Average click duration
#
#     c)  Time of the day (Morning/Afternoon/Night) when the user spends the most time on the platform (the time spent is tracked through the duration of the clicks)
#
#     d)  Is the user an old movie lover, or is he into more recent stuff (content released after 2010)?
#
#     e)  Average time spent a day by the user (considering only the days he logs in)
#
# So, in the end, you should have for each user_id five features.
#
# 3)  Consider at least 10 additional features that can be generated for each user_id (you can use chatGPT or other LLM tools for suggesting features to create). Describe each of them and add them to the previous dataset you made (the one with five features). In the end, you should have for each user at least 15 features (5 recommended + 10 suggested by you).

# %% [markdown]
# ---
#
# We want to build a new dataset of user features extracted from the current dataset. We start by creating a dataframe containing only `user_id` and we populate it each time we build a new feature.
#
# ---

# %%
# empty user dataframe
users_dataset_base = pd.DataFrame(original_dataset.user_id.unique(), columns = ["user_id"])

# %%
'''
    The first feature we want to build is:
    **Favorite genre (i.e., the genre on which the user spent the most time)**
    We can exploit the `explode` method of Pandas to get from each entry a new entry for each genre in the list:
'''

# create exploded dataframe
exploded_dataset = original_dataset.explode("genres")[["user_id", "genres", "duration"]]

# add together all values with same user_id and same genre
exploded_dataset = exploded_dataset.groupby(["user_id", "genres"]).sum()

# get most watched genre
exploded_dataset = exploded_dataset.groupby("user_id").idxmax()
exploded_dataset.duration = exploded_dataset.duration.apply(lambda row: row[1])

# rename column
exploded_dataset = exploded_dataset.rename(columns={'duration': 'favorite_genre'})

# merge into user dataset
users_dataset_base = users_dataset_base.merge(exploded_dataset, left_on = "user_id", right_index = True)



'''
    The second feature to extract is:
    **Average click duration**
    This is very fast as we have just to calculate the mean of the `duration` columns of every user:
'''

# get mean
mean_dataset = original_dataset.groupby("user_id").duration.mean().reset_index()

# rename column
mean_dataset = mean_dataset.rename(columns={'duration': 'mean_duration'})

# merge into user dataset
users_dataset_base = users_dataset_base.merge(mean_dataset)



'''
    The third feature feature is:
    **Time of the day (Morning/Afternoon/Night) when the user spends the most time on the platform (the time spent is tracked through the duration of the clicks)**

    We will use as delimitations between the three time parts:
    - Morning: 6 to 14
    - Afternoon: 14 to 20
    - Night: 20 to 6
'''

# create working dataframe substituting the whole datetime with hour
hours = original_dataset[["user_id", "datetime", "duration"]].copy()
hours.datetime = hours.datetime.dt.hour

# cluster hours into three time periods
hours.datetime = hours.datetime.apply(lambda x: 'morning' if 6 <= x < 14 else 'afternoon' if 14 <= x < 20 else 'night')

# get most active time period for each user
hours = hours.groupby(["user_id", "datetime"]).sum().groupby("user_id").idxmax()
hours.duration = hours.duration.apply(lambda row: row[1])

# rename column
hours = hours.rename(columns={'duration': 'favorite_time_day'})

# merge into user dataset
users_dataset_base = users_dataset_base.merge(hours, left_on = "user_id", right_index = True)



'''
    The fourth feature is:
    **Is the user an old movie lover, or is he into more recent stuff (content released after 2010)?**
'''

# convert all datetimes to only the year 
years = original_dataset[["user_id", "release_date"]].copy()
years.release_date = years.release_date.dt.year

# check if film is old or not
years["new"] = years.release_date > 2010
years["old"] = years.release_date <= 2010

# count for each user how many have release year > 2010 and how many not, use boolean value as new column
user_oldnew = years.groupby("user_id").old.sum() > years.groupby("user_id").new.sum()

# rename column
user_oldnew.name = "is_oldmovies_lover"

# merge into user dataset
users_dataset_base = users_dataset_base.merge(user_oldnew, left_on = "user_id", right_index = True)



'''
    The fifth feature is:
    **Average time spent a day by the user (considering only the days he logs in)**
'''

# we can just take the mean_duration column and divide it by the number of different days the same user has in the dataset.

# we count how many different days every user has logged in
days = original_dataset[["user_id", "datetime"]].copy()
days["datetime"] = days["datetime"].dt.floor('D')
days = days.groupby("user_id").datetime.nunique()

# we count the total duration per user
sums = original_dataset.groupby("user_id").duration.sum()

# divide total duration by number of days
average_per_day = sums / days

# rename column
average_per_day.name = "duration_per_day"

# merge into user dataset
users_dataset_base = users_dataset_base.merge(average_per_day, left_on = "user_id", right_index = True)

# %%
users_dataset_base
# Out:
#            user_id favorite_genre  mean_duration favorite_time_day  \
# 0       1dea19f6fe         Comedy       0.000000             night
# 1       544dcbc510          Drama    1553.750000         afternoon
# 2       7cbcc791bf         Action    4218.666667         afternoon
# 3       ebf43c36b6         Action    1883.533333         afternoon
# 4       a57c992287          Drama    3684.538462         afternoon
# ...            ...            ...            ...               ...
# 161913  45414be0ec         Comedy       0.000000         afternoon
# 161914  783ec67e84      Biography       0.000000         afternoon
# 161915  89c715f3a4      Adventure      -1.000000         afternoon
# 161916  9207e1499b      Biography   42592.000000             night
# 161917  57501964fd      Talk-Show     851.000000             night
#
#         is_oldmovies_lover  duration_per_day
# 0                     True          0.000000
# 1                    False      18645.000000
# ...

# %% [markdown]
# ---
#
# **The additional features we propose are:**
#
# - `watchtime`: the total watchtime of a certain user. It's the sum of all the durations.
# - `iterations`: the total number of iterations of a certain user. It's the number of rows related to that user.
# - `active_days`: the number of days the user has been active on the site.
# - `n_movies`: the number of unique movies watched by the user
# - `max_rewatches`: the maximum number of times the user has watched the same movie
# - `favorite_day`: the user favourite day of the week to watch movies. We search it by finding the day with the highest duration overall for that user
# - `favorite_month`: the user favourite month of the year to watch movies. We search it by finding the month with the highest duration overall for that user
# - `most_active_year`: the year the user has been most active on based on the duration.
# - `is_weekend_watcher`: if the user is a weekend watcher. We define a user "weekend watcher" if at least 50% of it's views are on saturday or sunday
# - `longest_iteration`: the longest iteration registered for the user. We search it by finding the max across all durations
#
# ---

# %%
# create empty user dataframe
users_dataset_extended = pd.DataFrame(original_dataset.user_id.unique(), columns = ["user_id"])

# %%
# watchtime feature
n_movies = original_dataset.groupby("user_id").duration.sum()
n_movies.name = "total watchtime"

users_dataset_extended = users_dataset_extended.merge(n_movies, left_on = "user_id", right_index = True)


# number of iterations feature
n_iterations = original_dataset.groupby("user_id").size()
n_iterations.name = "iterations"

users_dataset_extended = users_dataset_extended.merge(n_iterations, left_on = "user_id", right_index = True)


# number of active days feature
days_active = original_dataset[["user_id", "datetime"]].copy()
days_active["datetime"] = days_active["datetime"].dt.floor('D')
days_active = days_active.groupby("user_id").datetime.nunique()
days_active.name = "active_days"

users_dataset_extended = users_dataset_extended.merge(days_active, left_on = "user_id", right_index = True)


# number of unique movies feature
n_movies = original_dataset.groupby("user_id").movie_id.nunique()
n_movies.name = "n_movies"

users_dataset_extended = users_dataset_extended.merge(n_movies, left_on = "user_id", right_index = True)


# highest number of rewatches feature
rewatch = original_dataset.groupby(["user_id", "movie_id"]).size().groupby("user_id").max()
rewatch.name = "max_rewatches"

users_dataset_extended = users_dataset_extended.merge(rewatch, left_on = "user_id", right_index = True)


# favorite day of the week feature
favourite_day = original_dataset[["user_id", "datetime"]].copy()
favourite_day.datetime = favourite_day.datetime.dt.dayofweek
favourite_day = favourite_day.groupby(["user_id", "datetime"]).size().groupby("user_id").idxmax().apply(lambda x: x[1])
favourite_day.name = "favorite_day"

users_dataset_extended = users_dataset_extended.merge(favourite_day, left_on = "user_id", right_index = True)


# favorite month of the year feature
favourite_month = original_dataset[["user_id", "datetime"]].copy()
favourite_month.datetime = favourite_month.datetime.dt.month
favourite_month = favourite_month.groupby(["user_id", "datetime"]).size().groupby("user_id").idxmax().apply(lambda x: x[1])
favourite_month.name = "favorite_month"

users_dataset_extended = users_dataset_extended.merge(favourite_month, left_on = "user_id", right_index = True)


# most active year feature
most_active_year = original_dataset[["user_id", "datetime"]].copy()
most_active_year.datetime = most_active_year.datetime.dt.year
most_active_year = most_active_year.groupby(["user_id", "datetime"]).size().groupby("user_id").idxmax().apply(lambda x: x[1])
most_active_year.name = "most_active_year"

users_dataset_extended = users_dataset_extended.merge(most_active_year, left_on = "user_id", right_index = True)


# weekend person feature
def weekend_function(row):
    row = row.droplevel(0)
    row = row.reindex(range(7), fill_value=0)
    return (row[5] + row[6]) > (row[0] + row[1] + row[2] + row[3] + row[4])

weekend = original_dataset[["user_id", "datetime"]].copy()
weekend.datetime = weekend.datetime.dt.dayofweek
weekend = weekend.groupby(["user_id", "datetime"]).size()
weekend = weekend.groupby("user_id").apply(weekend_function)
weekend.name = "is_weekend_user"

users_dataset_extended = users_dataset_extended.merge(weekend, left_on = "user_id", right_index = True)


# longest iteration feature
longest_iteration = original_dataset.groupby("user_id").duration.max()
longest_iteration.name = "longest_iteration"

users_dataset_extended = users_dataset_extended.merge(longest_iteration, left_on = "user_id", right_index = True)

# %%
users_dataset_extended
# Out:
#            user_id  total watchtime  iterations  active_days  n_movies  \
# 0       1dea19f6fe              0.0           1            1         1
# 1       544dcbc510          18645.0          12            1         8
# 2       7cbcc791bf          25312.0           6            3         4
# 3       ebf43c36b6          28253.0          15            3        12
# 4       a57c992287          95798.0          26           13        22
# ...            ...              ...         ...          ...       ...
# 161913  45414be0ec              0.0           1            1         1
# 161914  783ec67e84              0.0           1            1         1
# 161915  89c715f3a4             -1.0           1            1         1
# 161916  9207e1499b          42592.0           1            1         1
# 161917  57501964fd            851.0           1            1         1
#
#         max_rewatches  favorite_day  favorite_month  most_active_year  \
# ...

# %% [markdown]
# ---
#
# And finally we merge the two datasets as we will need to work on them both in the following parts of the homework.
#
# ---

# %%
users_dataset = users_dataset_base.merge(users_dataset_extended)
users_dataset
# Out:
#            user_id favorite_genre  mean_duration favorite_time_day  \
# 0       1dea19f6fe         Comedy       0.000000             night
# 1       544dcbc510          Drama    1553.750000         afternoon
# 2       7cbcc791bf         Action    4218.666667         afternoon
# 3       ebf43c36b6         Action    1883.533333         afternoon
# 4       a57c992287          Drama    3684.538462         afternoon
# ...            ...            ...            ...               ...
# 161913  45414be0ec         Comedy       0.000000         afternoon
# 161914  783ec67e84      Biography       0.000000         afternoon
# 161915  89c715f3a4      Adventure      -1.000000         afternoon
# 161916  9207e1499b      Biography   42592.000000             night
# 161917  57501964fd      Talk-Show     851.000000             night
#
#         is_oldmovies_lover  duration_per_day  total watchtime  iterations  \
# 0                     True          0.000000              0.0           1
# ...

# %% [markdown]
# ### 2.2 Choose your features (variables)!

# %% [markdown]
# You may notice that you have plenty of features to work with now. So, it would be best to find a way to reduce the dimensionality (reduce the number of variables to work with). You can follow the subsequent directions to achieve it:
#
# 1)  *To normalise or not to normalise? That's the question*. Sometimes, it is worth normalizing (scaling) the features. Explain if it is a good idea to perform any normalization method. If you think the normalization should be used, apply it to your data (look at the available normalization functions in the `scikit-learn` library).
#
# 2)  Select **one** method for dimensionality reduction and apply it to your data. Some suggestions are Principal Component Analysis, Multiple Correspondence Analysis, Singular Value Decomposition, Factor Analysis for Mixed Data, Two-Steps clustering. Make sure that the method you choose applies to the features you have or modify your data to be able to use it. Explain why you chose that method and the limitations it may have.

# %% [markdown]
# ---
#
# In this task, we need to apply a dimensionality reduction to the dataset of the new features that we created in the previous step of this exercise. Given the mixed nature of the variables, Involving both numerical and categorical aspects, it would be appropriate to employ a dimensionality reduction technique called **Factor Analysis of Mixed Data (FAMD)**. FAMD combines a **Principal Component Analysis (PCA)** on the quantitative columns and a **Multiple Correspondence Analysis (MCA)** on the qualitative columns.
#
# However, before proceeding with this strategy, it is advisable to examine the correlation among quantitative variables and the association among categorical variables.
#
# ---

# %%
# Extract a partition of the new features dataset which contains only the quantitative varibles
quantitative_col = ['mean_duration', 'duration_per_day', 'total watchtime', 'iterations', 'active_days', 'n_movies','max_rewatches','longest_iteration', 'most_active_year']
quantitative_df= users_dataset[quantitative_col]

# Increase the size of the plot
plt.figure(figsize=(15, 10))

# Plot the correlation matrix with a specified color map
heatmap = sns.heatmap(quantitative_df.corr(), linewidths=0.5, vmin=-1, vmax=1, square=True,
                      cmap="viridis_r", linecolor='white', annot=True, fmt=".2f", cbar_kws={"shrink": 0.75})

plt.yticks(rotation=0)

# Customize the color bar using the mappable object from the heatmap
cbar = heatmap.collections[0].colorbar
cbar.set_label('Correlation', rotation=270, labelpad=15)

# Add a title
plt.title('Correlation Matrix of Quantitative Variables', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# From the previous table, a correlation close to $|1|$ is evident among the following pairs of variables:
#
# - `mean_duration` and `duration_per_day`;
# - `total watchtime` and `longest_iteration`;
# - `iterations` and `n_movies`.
#
# Since such a high value in the linear relationship coefficient implies redundancy of information between the respective variable pairs, it is advisable to remove one variable from each pair. This is because a high value in one column will necessarily result in a high absolute value in the other column (the sign is determined by the correlation coefficient's sign).
#
# While this removal is not strictly necessary, as perfectly correlated variables would yield eigenvalues equal to $0$ in the **PCA** (thus lacking in information) and would never be selected during the choice of the number of **Principal Components (PC)**, we have chosen to explicitly mention this step as it follows the correct procedure.
#
# Since the correlation of the `most_active_year` column is $0$ with all other variables, it is linearly independent. Therefore, we remove it since **PCA** would not be able to capture its variability.

# %%
# remove the perfectly correlated and linearly indipendent columns
quantitative_df.drop(["duration_per_day", "longest_iteration", 'iterations', 'most_active_year'], axis = 1, inplace = True)
quantitative_df
# Out:
#         mean_duration  total watchtime  active_days  n_movies  max_rewatches
# 0            0.000000              0.0            1         1              1
# 1         1553.750000          18645.0            1         8              3
# 2         4218.666667          25312.0            3         4              3
# 3         1883.533333          28253.0            3        12              2
# 4         3684.538462          95798.0           13        22              3
# ...               ...              ...          ...       ...            ...
# 161913       0.000000              0.0            1         1              1
# 161914       0.000000              0.0            1         1              1
# 161915      -1.000000             -1.0            1         1              1
# 161916   42592.000000          42592.0            1         1              1
# 161917     851.000000            851.0            1         1              1
#
# [161918 rows x 5 columns]

# %% [markdown]
# ---
#
# Now we want to perform the same check for categorical variables using an association matrix obtained with Cramer's V index with bias correction ($\widetilde{V}$). It relies on the chi-square test to assess whether there is a significant relationship between variables, normalizing the values to range from 0 to 1, where 0 indicates no association and 1 indicates complete association.
#
# This index is calculated with the following formula starting from a $k \times r$ matrix:
# $$ \widetilde{V} = \sqrt{ \frac{max(0, \phi^2 - \frac{(k-1)(r-1)}{n-1})}{min(k- \frac{(k-1)^2}{n-1},r- \frac{(r-1)^2}{n-1})}} \qquad \text{where} \qquad \phi^2 = \frac{\chi^2}{n} $$

# %%
def cramers_v(confusion_matrix):
    # Calculate the chi-squared statistic from the contingency matrix
    chi2 = chi2_contingency(confusion_matrix)[0]

    # Calculate the total number of observations (total number of rows) in the contingency matrix
    n = confusion_matrix.sum().sum()

    # Calculate phi-squared which is a measure of association strength
    phi2 = chi2 / n

    # Calculate corrected phi-squared 
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))

    # Calculate the number of rows and columns after correction
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)

    # Calculate and return Cramér's V with bias correction
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

def association_matrix(data_frame):
    # Get the column names (variables) of the DataFrame
    columns = data_frame.columns

    # Create an empty DataFrame to store the association matrix
    matrix = pd.DataFrame(index=columns, columns=columns, dtype=float)

    # Iterate over pairs of columns and compute Cramér's V for each pair
    for col1, col2 in combinations(columns, 2):
        # Create a contingency table for the pair of variables
        contingency_table = pd.crosstab(data_frame[col1], data_frame[col2])

        # Calculate Cramér's V with bias correction using the previously defined function
        matrix.loc[col1, col2] = cramers_v(contingency_table)

        # Set the symmetric value on the association matrix
        matrix.loc[col2, col1] = matrix.loc[col1, col2]

    # Set the diagonal elements to 1.0
    np.fill_diagonal(matrix.values, 1.0)
    
    # Return the final association matrix
    return matrix

# %%
# Extract the categorical varible
qualitative_col = ['favorite_genre', 'favorite_time_day','is_oldmovies_lover','favorite_day', 'favorite_month', 'is_weekend_user']
qualitative_df= users_dataset[qualitative_col]

# Setting of the plot size
plt.figure(figsize=(15, 10))

# Plot the Association matrix with a specified color map
heatmap = sns.heatmap(association_matrix(qualitative_df), linewidths=0.5, vmin=0, vmax=1, square=True,
                      cmap="Reds", linecolor='white', annot=True, fmt=".2f", cbar_kws={"shrink": 0.75})

plt.yticks(rotation=0)

# Customization of the color bar 
cbar = heatmap.collections[0].colorbar
cbar.set_label('Association', rotation=270, labelpad=15)

plt.title('Association Matrix of Categorical Variables', fontsize=16)
plt.show()

# %% [markdown]
# From the examination of the association matrix, we immediately notice how all pairs of categorical variables appear to be independent (Cramér's V $\approx 0$), with the exception of the pair `is_weekend_user` and `favorite_day`, which exhibits complete association (Cramér's V $\approx 1$). In the first case, the near-zero values make it challenging to identify a relationship between variables, while in the second case, the relationship is so strong that it renders the information redundant.
#
# In light of this result, it is evident that a dimensionality reduction through **MCA** would struggle to explain the variability of the phenomenon with a limited number of **Principal Components (PC)**, negatively impacting even a **FAMD** applied to the entire dataset.

# %%
# Remove the redundant information
qualitative_df.drop([ "favorite_day"], axis = 1, inplace = True)

# Create a MCA model
mca = MCA(
    n_components=pd.get_dummies(qualitative_df).shape[1],  # Extract all the PC of the categorical dataset after the one-hot encoding
    n_iter=3,                   # Number of iterations for the power method to compute eigenvectors
    copy=True,                  # Use a copy of the dataset in order to prevent side-effects on the input data
    check_input=True,           # Check the consistency of the dataset --> for istance: dtype, non-empty, etc.
    engine='sklearn',           # MCA algorithm engine 
    random_state=30             # Seed for reproducibility of the result since the prince package use a randomised version of SVD 
                                # which is faster than the standard SVD
)
mca = mca.fit(qualitative_df)

# Print the first 5 CP of the MCA
# We can see how bad the MCA explain the varibility of the data
print("MCA-output")
mca.eigenvalues_summary.head(4)
# Out:
# MCA-output
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              0.246         2.99%                      2.99%
# 1              0.226         2.76%                      5.76%
# 2              0.219         2.67%                      8.43%
# 3              0.214         2.61%                     11.03%

# %%
# Create a FAMD model 
famd = FAMD(
    n_components=5,             # Number of PC we want to extract to show how bad the FAMD performs
    n_iter=3,                   # Number of iterations for the power method to compute eigenvectors
    copy=True,                  # Use a copy of the dataset in order to prevent side-effects on the input data
    check_input=True,           # Check the consistency of the dataset --> for istance: dtype, non-empty, etc.
    engine='sklearn',           # FAMD algorithm engine 
    random_state=30             # Seed for reproducibility of the result since the prince package use a randomised version of SVD 
                                # which is faster than the standard SVD
)

# Fit the FAMD model to the dataset (we have removed quantitative correlated/linearly indipendent columns)
famd.fit(pd.concat([quantitative_df, qualitative_df], axis=1))

# Print the first 5 CP of the FAMD
# We can see how bad the FAMD explain the varibility of the data
print("FAMD-output")
famd.eigenvalues_summary
# Out:
# FAMD-output
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              9.633         1.03%                      1.03%
# 1              8.655         0.93%                      1.96%
# 2              7.702         0.82%                      2.78%
# 3              7.646         0.82%                      3.60%
# 4              7.181         0.77%                      4.37%

# %% [markdown]
# Therefore, given the impossibility of adequately summarizing categorical data, we will proceed only with a dimensionality reduction of quantitative data through **PCA**.
#
# ---
#
# **PCA** aims to explain as much variability as possible in the total dataset variability while reducing the number of columns. Therefore, it seeks to minimize the inevitable loss of information. A column with an order of magnitude much larger than the other variables will necessarily have higher variability in absolute terms. Since **PC** tend to explain columns with higher variability first, it is necessary to *normalize* the data in order to rescale this information, ensuring that the unit of measurement does not influence the construction of the Principal Components.
#
# These steps are performed automatically by the `prince` package through the parameters `rescale_with_mean` e `rescale_with_std`.

# %%
# Create a PCA model with the 'prince' package
pca = PCA(
    n_components=quantitative_df.shape[1],   # Number of principal components to retain --> first we select all the possible PC
    n_iter=3,                   # Number of iterations for the power method to compute eigenvectors
    rescale_with_mean=True,     # Rescale the data by subtracting the mean
    rescale_with_std=True,      # Rescale the data by dividing by the standard deviation
    copy=True,                  # Use a copy of the dataset in order to prevent side-effects on the input data
    check_input=True,           # Check the consistency of the dataset --> for istance: dtype, non-empty, etc.
    engine='sklearn',           # PCA algorithm engine 
    random_state=30             # Seed for reproducibility of the result since the prince package use a randomised version of SVD 
                                # which is faster than the standard SVD
)

# Fit the PCA model to the quantitative dataset
pca = pca.fit(quantitative_df)

# Print a summary of the eigenvalues
pca.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              2.399        47.98%                     47.98%
# 1              1.525        30.50%                     78.49%
# 2              0.716        14.31%                     92.80%
# 3              0.247         4.94%                     97.74%
# 4              0.113         2.26%                    100.00%

# %% [markdown]
# We represent the trend of cumulative explained variance with a *Scree plot*. Through the identification of the "elbow" on the plot, we find the ideal number of **Principal Components**, in this case, equal to $3$.

# %%
# Set the dimensions of the plot
plt.rcParams["figure.figsize"] = (15, 10)

# Create the axis values of the plot
xi = np.arange(1, 6, step=1)
y = pca.cumulative_percentage_of_variance_

# Set the plot
sns.set(style="whitegrid")
sns.lineplot(x=xi, y=y, marker='o', color='dodgerblue')
plt.xlabel('Number of Principal Components')
plt.xticks(np.arange(1, 6, step=1))
plt.ylabel('Cumulative Variance Explained (%)')
plt.title('Scree Plot')
plt.ylim(0, 100)
plt.yticks(np.arange(0, 101, step=10))

# Add a light grid
plt.grid(alpha=0.5)


plt.axvline(x=3, color='darkgreen', linestyle='--', label='Number of PC chosen')
plt.legend()

# Remove top and right borders
sns.despine()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Although with three **Principal Components** we know that we represent the total variability of the dataset well, we also want to verify that each individual variable is well summarized by the chosen solution. To do this, we observe the value of the *Communality*, which precisely summarizes how well the chosen PC all together explain the variability of each column.
#
#
# To do this, we need to manually calculate the values by summing the square of each column coordinates.

# %%
# Create a PCA model with the 'prince' package
pca = PCA(
    n_components=3,             # Extract only the first 3 principal components (PC)
    n_iter=3,                   # Number of iterations for the power method to compute eigenvectors
    rescale_with_mean=True,     # Rescale the data by subtracting the mean
    rescale_with_std=True,      # Rescale the data by dividing by the standard deviation
    copy=True,                  # Use a copy of the dataset in order to prevent side-effects on the input data
    check_input=True,           # Check the consistency of the dataset --> for istance: dtype, non-empty, etc.
    engine='sklearn',           # PCA algorithm engine 
    random_state=30             # Seed for reproducibility of the result since the prince package use a randomised version of SVD 
                                # which is faster than the standard SVD
)

# Fit the PCA model to the quantitative dataset
pca = pca.fit(quantitative_df)

# Calculate communalities as the sum of squared column coordinates
communalities = (pca.column_coordinates_ ** 2).sum(axis=1)

# Create a DataFrame to visualize the results
communalities_df = pd.DataFrame(index=quantitative_df.columns, data={'Communality': communalities})

# Sort the DataFrame in descending order of Communality
communalities_df = communalities_df.sort_values(by='Communality', ascending=False).reset_index()

# Rename the index as Variable
communalities_df = communalities_df.rename(columns={'index': 'Variable'})

# Plot the Communalities
communalities_df
# Out:
#           Variable  Communality
# 0    max_rewatches     0.997128
# 1         n_movies     0.938434
# 2      active_days     0.936744
# 3    mean_duration     0.895610
# 4  total watchtime     0.871986

# %% [markdown]
# From the previous table, it can be observed that each individual variable is well explained, as expected since that the percentage of total explained variability is around $\approx 93\%$. However, it is interesting to note that this number of Principal Components is necessary, as taking only $2$ components would have explained only $\approx 43\%$ of the `total watchtime` column (to observe this information, simply run again the previous cell, changing the `n_components` parameter to $2$ or you can just trust us).

# %% [markdown]
# ---
#
# Once the number of **PC** is defined, it is advisable to give a name that explains the meaning of the indices. To do this, we will examine the **Factor Pattern**, which shows the correlation between each column and the Principal Components.

# %%
# Factor pattern
round(pca.column_correlations,2)
# Out:
# component           0     1     2
# variable
# mean_duration    0.25  0.91  0.05
# total watchtime  0.64  0.68 -0.01
# active_days      0.91 -0.28 -0.19
# n_movies         0.86 -0.29 -0.34
# max_rewatches    0.61 -0.26  0.75

# %% [markdown]
# Recalling from the correlation matrix of the quantitative variable that a high value of the feature `mean_duration` implied a high value of the feature `duration_per_day` and the same is for `total watchtime` with `longest_iteration` and `n_movies` with `iterations` then we can say that:
#
# - 1st. PC It's a rising indenx of the most active users
#
# - 2nd. PC It's a rising index of occasional users who, whenever they can, spend much time on Netflix..
#
# - 3rd. PC It's a rising index of users who likes rewatching the same titles

# %% [markdown]
# ---
#
# As we have decided to keep the qualitative variables since they are independent of each other, we can represent the users in the CP plane by highlighting the characteristic they assume in one of these categorical variables. For illustrative purposes, the `is_weekend_user` feature has been chosen.

# %%
# Obtain the PCA dataset
pca_df = pca.fit_transform(quantitative_df)

# Rename the PC
pca_df = pca_df.rename(columns={0: 'Active_users', 1: 'Occasional_high_watchtime', 2: 'Rewatchers'})

#Save the reduced dataset into a .csv file 
pca_df.to_csv('pca_df.csv', index=False)

# %%
# Obtain the reduced dataset by combining the PCA dataset with the qualitative variables + the quantitative linearly indipendent column
# Note that we havent added the favourite_day column since it is redundat  --> see Association matrix
reduced_df = pd.concat([pca_df, users_dataset['most_active_year'], qualitative_df], axis=1)

# Rename the PC
reduced_df = reduced_df.rename(columns={0: 'Active_users', 1: 'Occasional_high_watchtime', 2: 'Rewatchers'})

# Apply a vectorization on the two categorical columns that are saved into a sfring format
label_encoder = LabelEncoder()

# favorite_time_day conversion
reduced_df['favorite_time_day'] = label_encoder.fit_transform(reduced_df['favorite_time_day'])

# Save a legend of the conversion
time_day_dict = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# favorite_genre conversion
reduced_df['favorite_genre'] = label_encoder.fit_transform(reduced_df['favorite_genre'])

# Save a legend of the conversion
fav_genre_dict = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# Convert the Boolean columns into a dummy 
reduced_df['is_oldmovies_lover'] = reduced_df['is_oldmovies_lover'].astype(int)
reduced_df['is_weekend_user'] = reduced_df['is_weekend_user'].astype(int)

# Save the reduced dataset into a .csv file 
reduced_df.to_csv('reduced_df.csv', index=False)

reduced_df
# Out:
#         Active_users  Occasional_high_watchtime  Rewatchers  most_active_year  \
# 0          -0.986586                  -0.052635   -0.150417              2017
# 1           0.533446                  -0.725637    0.526028              2017
# 2           0.443426                  -0.641732    0.748843              2017
# 3           1.180740                  -0.933378   -0.679519              2017
# 4           4.928811                  -2.341591   -1.742313              2017
# ...              ...                        ...         ...               ...
# 161913     -0.986586                  -0.052635   -0.150417              2019
# 161914     -0.986586                  -0.052635   -0.150417              2019
# 161915     -0.986588                  -0.052641   -0.150417              2019
# 161916     -0.897864                   0.200082   -0.136066              2019
# 161917     -0.984813                  -0.047585   -0.150130              2019
#
# ...

# %%
# Extract the principal components
x = reduced_df.iloc[:, 0]
y = reduced_df.iloc[:, 1]
z = reduced_df.iloc[:, 2]

# Create a 3D plot
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(111, projection='3d')

# Color the users based on a categorical variable
category_column = reduced_df['is_weekend_user']
scatter = ax.scatter(x, y, z, c=category_column, cmap='viridis', marker='o', alpha=0.7)

# Set the labels for the axes
ax.set_xlabel('Active_users')
ax.set_ylabel('Occasional_high_watchtime')
ax.set_zlabel('Rewatchers')

# Set the title
plt.title('3D Scatter Plot of PCA')

# Set the perspective of the plot
ax.view_init(elev=20, azim=25)

# Add a legend 
legend = ax.legend(*scatter.legend_elements(), title='Categories')
ax.add_artist(legend)

# Show the plot
plt.show()

# %% [markdown]
# ### 2.3 Clustering!

# %% [markdown]
# 1)  Implement the K-means clustering algorithm (**not** ++: random initialization) using MapReduce. We ask you to write the algorithm from scratch following what you learned in class.
#
# 2)  Find an optimal number of clusters. Use at least two different methods. If your algorithms provide diverse optimal K's, select one of them and explain why you chose it.
#
# 3)  Run the algorithm on the data obtained from the dimensionality reduction.
#
# 4)  Implement **K-means++** from scratch and explain the differences with the results you got earlier.
#
# 5)  Ask ChatGPT to recommend other clustering algorithms and choose one. Explain your choice, then ask ChatGPT to implement it or use already implemented versions (e.g., the one provided in the scikit-learn library) and run it on your data. Explain the differences (if there are any) in the results. Which one is the best, in your opinion, and why?

# %% [markdown]
# #### 1)  Implement the K-means clustering algorithm (not ++: random initialization) using MapReduce. We ask you to write the algorithm from scratch following what you learned in class:

# %%
def k_means(data, n_clusters, max_iterations):
    # create local spark session
    sc = SparkContext("local", "KMeans")

    # convert data in pyspark format
    data = sc.parallelize(data)

    # initiazation
    # the initial cluster representatives among all points at random, without replacement
    representatives = data.takeSample(False, n_clusters)

    # we execute a fixed number of iterations, if we don't find convergence first
    for _ in range(max_iterations):

        # the first map operation of the algorithm finds which elements belong to which cluster
        # by calculating the distance of each element with every centroid and taking the one that
        # minimizes the euclidean distance
        # the output element is composed as follows:
        # [ cluster_id, (points coordinates, accumulator) ]
        # the accumulator is a variable that will help us keep track of how many points are inside a
        # cluster, it will be necessary to calculate the mean later
        closest = data.map(lambda row: (np.argmin([np.linalg.norm(row - r) for r in representatives]), (row, 1)))

        # the first reduce operation of the algorithm calculate the sum of all alements that belong to a
        # certain cluster. this will group values by the first element (the cluster they belong) and sum
        # both elements of the tuple
        sums = closest.reduceByKey(lambda row1, row2: (row1[0] + row2[0], row1[1] + row2[1]))

        # finally we execute a new map operation to calculate the mean, obtaining the new representatives
        # for every cluster it takes the corresponding tuple containing the sum of all the points of the
        # cluster and the number of points and execute a division, obtaining the mean
        old_representatives = representatives
        representatives = sums.map(lambda cluster_sum: cluster_sum[1][0] / cluster_sum[1][1]).collect()
        
        # if all the old and the new representatives are the same we have found convergence and won't
        # need additional iterations
        if (np.equal(old_representatives, representatives).all()):
            print("Convergence found!")
            break

    clustered_points = []
    for point in closest.collect():
        # [cluster_id | coordinates]
        clustered_points.append((point[0], point[1][0]))

    # stop spark session
    sc.stop()

    return representatives, clustered_points

# %% [markdown]
# ---
#
# Test on example to check correctness. We will use 2D sample data to be able to plot the results. We generate clustered data with the method `sklearn.datasets.makeblobs()` and apply our k-means algorithm over it.
#
# ---

# %%
# generating data points
n_clusters = 3 # number of clusters to generate
cluster_test_data, _ = make_blobs(n_samples = n_clusters * 100, centers = n_clusters, random_state = 42) # seed for reproducibility

# plot
plt.rcParams.update(plt.rcParamsDefault)
plt.scatter(cluster_test_data[:, 0], cluster_test_data[:, 1])
plt.title("Generated Data Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# execute k_means
centroids, closest = k_means(cluster_test_data, n_clusters, 10)
# Out:
# Convergence found!

# %%
# group by cluster
clustered_points = {i: [] for i in range(n_clusters)}
for point in closest:
    clustered_points[point[0]].append(point[1])

# plot points
for i in range(n_clusters):
    cluster_data = np.array(clustered_points[i])
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], label = "Cluster" + str(i + 1))

# plot centroids
centroids = np.array(centroids)
plt.scatter(centroids[:, 0], centroids[:, 1], marker = "*", s = 100, color = "black", label = "Centroids")

plt.title("K-means clustering")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# In the specific case of the current execution it seems that we have ended in a local minimum. This will be particularly useful to show how the use of k-means++ can help us by reducing the probability to end up in such cases.
#
# ---

# %% [markdown]
# #### 2)  Find an optimal number of clusters. Use at least two different methods. If your algorithms provide diverse optimal K's, select one of them and explain why you chose it:

# %% [markdown]
# **Attention!**
#
# Since the K-Means algorithm operates on the Euclidean distances between points in the dataset and the centroids, it is necessary to apply this classification method only to the **Principal Components obtained** through **PCA**, rather than the entire reduced dataset. This approach excludes linearly independent qualitative variables, as it is impossible to calculate the distance metric used by K-Means on them, given that these variables are not numerically continuous.
#
# However, to apply the K-means algorithm, it is necessary to preselect the number of clusters. To this end, we have various criteria for selection.

# %% [markdown]
# ##### **Method 1: Selection through hierarchical clustering**

# %% [markdown]
# By applying hierarchical clustering and visualizing its dendrogram, we can observe the fusion level of clusters (vertical axis), which measures the diversity between the just-aggregated groups. From the underlying theory, we know that fusion levels increase as the number of clusters decreases because, with increased aggregations, internal variability worsens. Therefore, we choose the number of clusters as the range of values from which the fusion levels show clear increments.
#
# However, since our dataset consists of many rows, it is necessary to extract a smaller sample to obtain results within reasonable timeframes.

# %%
# Extract a salple of the PCA output
pca_df_sample = pca_df.sample(10000)

sns.set(style="whitegrid", font_scale=1.2)                          # Set the plot style
plt.figure(figsize=(20, 8))                                         # Set the plot shapes
dendrogram(linkage(pca_df_sample, method='ward'), no_labels=True)   # Plot the Dendrogram using the 'ward' method

# Add title and labels
plt.title('Dendrogramm', fontsize=16)
plt.xlabel('Users')
plt.ylabel('Fusion level')

sns.despine() # Remove the top an right border

# Show the plot
plt.show()

# %% [markdown]
# ##### **Method 2: Elbow Method on WCSS**

# %% [markdown]
# The **Within-Cluster Sum of Squares (WCSS)** is a measure of the compactness or cohesion of clusters in a clustering algorithm. It quantifies how close data points within a cluster are to the centroid of that cluster. The *Elbow Method* is a graphical technique based on the analysis of the **WCSS** measure as the number of clusters varies. By definition, as the number of clusters increases the **WCSS** will decrease because the clusters will become more specific. However, it will reach a point where the increase in the number of clusters leads to a diminishing marginal gain in WCSS reduction, forming an "*elbow*" in the graph. The number of clusters corresponding to the point where this "*elbow*" is observed is commonly chosen as the optimal number of clusters to use in the K-Means model.
#
# This methodology is included in the `Yellowbrick` package, and thanks to the `timings` parameter of the `KElbowVisualizer`, it also shows how much time is required to train the K-Means model for different numbers of clusters. The "metric" to get what we need is "distortion", defined by the documentation as "*mean sum of squared distances to centers*".

# %%
from sklearn.cluster import KMeans

# Plot the Elbow Method based on the WCSS measure
visualizer = KElbowVisualizer(KMeans(n_init='auto'), k = (2, 10), timings = True, metric = "distortion")
visualizer.fit(pca_df)
visualizer.show();

# %% [markdown]
# ##### **Method 3: Silhouette Score Method**

# %% [markdown]
# The **Silhouette value** measures how similar a point is to its own cluster compared to other clusters. It ranges from -1 to 1, where:
#
# - Values close to $1$ indicate that the point is well-assigned to its own cluster and far from others;
# - Values close to $0$ indicate overlap or confusion between clusters;
# - Values close to $-1$ indicate that the point might have been assigned to the wrong cluster.
#
# For the entire dataset, the overall **Silhouette Score** is the average of the silhouette values for all points. Generally, a higher Silhouette Score suggests better clustering quality.
#
# Due to computational limitations of this method, we need to extract a sample from our dataset and calculate the **Silhouette Score** on it using the `KElbowVisualizer` function from the `Yellowbrick` package, with the parameter `metric='silhouette'`, described by the documentation as "*mean ratio of intra-cluster and nearest-cluster distance*".

# %%
from sklearn.cluster import KMeans

# Plot the Silhouette Score of the sample of the PCA dataset
visualizer = KElbowVisualizer(KMeans(n_init='auto'), k = (2, 10), timings = True, metric = "silhouette")
visualizer.fit(pca_df_sample)
visualizer.show();

# %% [markdown]
# From the results obtained from the three previous methodologies, we have concluded that the best number of clusters is $2$ or $3$. This is because both have very high values in the **Silhouette Method** and show a significant increase in the **Fusion level** in the dendrogram but, for the **Elbow Method** these values are far from optimal. However, since this criterion only considers the internal cohesion of the groups, we consider the results of the **Silhouette Score** more robust.
#
# To decide which solution is effectively better between the two proposals, we believe that the best method is to try both and compare the results.

# %% [markdown]
# #### 3)  Run the algorithm on the data obtained from the dimensionality reduction:

# %% [markdown]
# As we have already explained in section $2.2$, we apply clustering based only on the quantitative variables obtained through **PCA** and evaluate the classification results for both $k=2$ clusters and $k=3$ clusters.

# %%
# Import the reduced dataset and the PCA dataset
reduced_df = pd.read_csv('reduced_df.csv')
pca_df = pd.read_csv('pca_df.csv')

# Apply the k-means with map reduce on the PCA dataset with k=3
centroids, closest = k_means(pca_df.values, 3, 50)

# Add the Cluster columns on the Reduced dataset
reduced_df.insert(0, 'Cluster', list(map(itemgetter(0), closest)))
# Out:
# Convergence found!

# %% [markdown]
# Now we color the **Principal Components** based on their cluster assignment.

# %%
# Extract the principal components
x = reduced_df.iloc[:, 1]
y = reduced_df.iloc[:, 2]
z = reduced_df.iloc[:, 3]

# Create a 3D plot
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(111, projection='3d')

# Color the users based on the Cluster
category_column = reduced_df['Cluster']
scatter = ax.scatter(x, y, z, c=category_column, cmap='viridis', marker='o', alpha=0.7)

# Set the labels for the axes
ax.set_xlabel('Active_users')
ax.set_ylabel('Occasional_high_watchtime')
ax.set_zlabel('Rewatchers')

# Set the title
plt.title('3D Scatter Plot of PCA')

# Set the perspective of the plot
ax.view_init(elev=25, azim=120)

# Add a legend 
legend = ax.legend(*scatter.legend_elements(), title='Cluster')
ax.add_artist(legend)

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# And let's check the performance of the clustering by measuring its silhouette score. In general a silhouette score above 0.5 is considered good.
#
# ---

# %%
score = silhouette_score(reduced_df[["Active_users", "Occasional_high_watchtime", "Rewatchers"]], reduced_df["Cluster"], sample_size = 10000)
print("Silhouette score:", score)
# Out:
# Silhouette score: 0.6632729628076064

# %% [markdown]
# Now let's do the same things with $k=2$.

# %%
# Import again the Reduced dataset
reduced_df2 = pd.read_csv('reduced_df.csv')

# Apply the k-means with map reduce on the PCA dataset with k=2
centroids2, closest2 = k_means(pca_df.values, 2, 50)

# Add the Cluster columns on the Reduced dataset
reduced_df2.insert(0, 'Cluster', list(map(itemgetter(0), closest2)))
# Out:
# Convergence found!

# %%
# Extract the principal components
x = reduced_df2.iloc[:, 1]
y = reduced_df2.iloc[:, 2]
z = reduced_df2.iloc[:, 3]

# Create a 3D plot
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(111, projection='3d')

# Color the users based on a categorical variable
category_column = reduced_df2['Cluster']
scatter = ax.scatter(x, y, z, c=category_column, cmap='viridis_r', marker='o', alpha=0.7)

# Set the labels for the axes
ax.set_xlabel('Active_users')
ax.set_ylabel('Occasional_high_watchtime')
ax.set_zlabel('Rewatchers')

# Set the title
plt.title('3D Scatter Plot of PCA')

# Set the perspective of the plot
ax.view_init(elev=25, azim=120)

# Add a legend 
legend = ax.legend(*scatter.legend_elements(), title='Cluster')
ax.add_artist(legend)

# Show the plot
plt.show()

# %%
score = silhouette_score(reduced_df2[["Active_users", "Occasional_high_watchtime", "Rewatchers"]], reduced_df2["Cluster"], sample_size = 10000)
print("Silhouette score:", score)
# Out:
# Silhouette score: 0.6647290014667229

# %% [markdown]
# ---
#
# **4)  Implement **K-means++** from scratch and explain the differences with the results you got earlier.**
#
# ---

# %%
def k_means_plus_plus(data, n_clusters, max_iterations):
    # initiazation

    # choose the first centroid randomly
    representatives = [data[np.random.randint(data.shape[0])]]

    for _ in range(1, n_clusters):
        # calculate squared distances from each point to the nearest centroid
        dists = np.array([min([np.linalg.norm(d - r)**2 for r in representatives]) for d in data])

        # array of probability for each point to be taken
        # if a point is already a representative the probanility will be zero
        # and it will not be extracted again
        probs = dists / dists.sum()

        # random extraction
        new = data[np.random.choice(len(data), p = probs)]

        # add as new cluster representative
        representatives.append(new)
    
    # create local spark session
    sc = SparkContext.getOrCreate()

    # convert data in pyspark format
    data = sc.parallelize(data)
    
    # the rest of the algorithm is the same as before
    for _ in range(max_iterations):

        closest = data.map(lambda row: (np.argmin([np.linalg.norm(row - r) for r in representatives]), (row, 1)))

        sums = closest.reduceByKey(lambda row1, row2: (row1[0] + row2[0], row1[1] + row2[1]))

        old_representatives = representatives
        representatives = sums.map(lambda cluster_sum: cluster_sum[1][0] / cluster_sum[1][1]).collect()
        
        if (np.equal(old_representatives, representatives).all()):
            print("Convergence found!")
            break

    clustered_points = []
    for point in closest.collect():
        # [cluster_id | coordinates]
        clustered_points.append((point[0], point[1][0]))

    # stop spark session
    sc.stop()

    return representatives, clustered_points

# %%
# execute k_means
centroids, closest = k_means_plus_plus(cluster_test_data, n_clusters, 10)
# Out:
# Convergence found!

# %%
# group by cluster
clustered_points = {i: [] for i in range(n_clusters)}
for point in closest:
    clustered_points[point[0]].append(point[1])

# plot points
for i in range(n_clusters):
    cluster_data = np.array(clustered_points[i])
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], label = "Cluster" + str(i + 1))

# plot centroids
centroids = np.array(centroids)
plt.scatter(centroids[:, 0], centroids[:, 1], marker = "*", s = 100, color = "black", label = "Centroids")

plt.title("K-means clustering")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# And we now apply it to our data:
#
# ---

# %%
# Import again the Reduced dataset
reduced_df3 = pd.read_csv('reduced_df.csv')

# Apply the k-means with map reduce on the PCA dataset with k=2
centroids3, closest3 = k_means_plus_plus(pca_df.values, 3, 50)

# Add the Cluster columns on the Reduced dataset
reduced_df3.insert(0, 'Cluster', list(map(itemgetter(0), closest3)))
# Out:
# Convergence found!

# %%
# Extract the principal components
x = reduced_df3.iloc[:, 1]
y = reduced_df3.iloc[:, 2]
z = reduced_df3.iloc[:, 3]

# Create a 3D plot
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(111, projection='3d')

# Color the users based on a categorical variable
category_column = reduced_df3['Cluster']
scatter = ax.scatter(x, y, z, c=category_column, cmap='viridis_r', marker='o', alpha=0.7)

# Set the labels for the axes
ax.set_xlabel('Active_users')
ax.set_ylabel('Occasional_high_watchtime')
ax.set_zlabel('Rewatchers')

# Set the title
plt.title('3D Scatter Plot of PCA')

# Set the perspective of the plot
ax.view_init(elev=25, azim=120)

# Add a legend 
legend = ax.legend(*scatter.legend_elements(), title='Cluster')
ax.add_artist(legend)

# Show the plot
plt.show()

# %%
score = silhouette_score(reduced_df3[["Active_users", "Occasional_high_watchtime", "Rewatchers"]], reduced_df3["Cluster"], sample_size = 10000)
print("Silhouette score:", score)
# Out:
# Silhouette score: 0.6731213514675591

# %% [markdown]
# ---
#
# We notice a slight increase over the silhouette from k-means to k-means++.
#
# ---

# %% [markdown]
# ---
#
# **5)  Ask ChatGPT to recommend other clustering algorithms and choose one. Explain your choice, then ask ChatGPT to implement it or use already implemented versions (e.g., the one provided in the scikit-learn library) and run it on your data. Explain the differences (if there are any) in the results. Which one is the best, in your opinion, and why?**
#
# ---

# %% [markdown]
# We have written the following prompt to ChatGPT 3.5: `Recommend me a list of clustering algorithm different from k-means and k-means++` and got a list of several different clustering algorithms together with a brief description of them and we decided to take the one that seemd the most coherent to use on our dataset, `Mean Shift Clustering`. As both chatGPT and the documentation of sklearn explain us this algorithm is still a centroid-based algorithm  as k-means but it is based on `kernel density estimation`, a technique which is used to estimate a distribution from a sample of the population it generates. Mean Shift has a major advantage in scenarios like ours: it does not require to know the number of clusters beforehand as it is capable of reasonably estimate them via the creation of multiple candidates.
#
# This together with a higher resistance to outliers make it a great choice in scenarios like the one we are in, but the cost of those strengths over k-means is an increased computational cost.
#
# We show an example execution on test data we used before:

# %%
# create mean shift istance
meanshift = MeanShift()

# execute meanshift
meanshift.fit(cluster_test_data)

# show plot of results

centroids = meanshift.cluster_centers_

# plot points
for i in range(n_clusters):
    cluster_data = np.array(clustered_points[i])
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], label = "Cluster" + str(i + 1))

# plot clusters
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', color='black', s=100, label='Cluster Centers')
plt.title('MeanShift Clustering')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# The results on the example data are clear and the same that we got with k-means. The clusters are well divided and the Mean Shift algorithm managed to get all three. We can now try to apply it to our real data:
#
# ---

# %%
# mean shift on real data

# we take a subset of the whole dataset
mean_shift_df = pca_df.sample(10000)

# create mean shift istance
meanshift = MeanShift()

# execute mean shift
cluster_labels = meanshift.fit_predict(mean_shift_df)

# add the Cluster columns on the dataset
mean_shift_df["Cluster"] = cluster_labels

# %%
# plot results

# Extract the principal components
x = mean_shift_df.iloc[:, 1]
y = mean_shift_df.iloc[:, 2]
z = mean_shift_df.iloc[:, 3]

# Create a 3D plot
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(111, projection='3d')

# Color the users based on a categorical variable
category_column = mean_shift_df['Cluster']
scatter = ax.scatter(x, y, z, c=category_column, cmap='viridis_r', marker='o', alpha=0.7)

# Set the labels for the axes
ax.set_xlabel('Active_users')
ax.set_ylabel('Occasional_high_watchtime')
ax.set_zlabel('Rewatchers')

# Set the title
plt.title('3D Scatter Plot of PCA')

# Set the perspective of the plot
ax.view_init(elev=25, azim=120)

# Add a legend 
legend = ax.legend(*scatter.legend_elements(), title='Cluster')
ax.add_artist(legend)

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# As the test data was simple we didn't noticed, but using the real data, that has both a high number of samples and higher dimensionality, we notice a great increase in computational time for Mean Shift clustering. We have been forced to show the results only on a subset of the whole dataset as the computation on the whole dataset seems to take more than 6 hours, however the results may be different from what we would expect on the complete dataset as the data are more sparse and therefore more likely to create an higher number of clusters.
#
# While this algorithm has some advantages over k-means in some scenarios the increased computational time seems to make it unseasable for big datasets, for this reason we consider k-means a better clustering algorithm in our case.
#
# ---

# %% [markdown]
# ### 2.4 Analysing your results!

# %% [markdown]
# You are often encouraged to explain the main characteristics that your clusters have. The latter is called the *Characterizing Clusters* step. Thus, follow the next steps to do it:
#
# 1)  Select 2-3 variables you think are relevant to identify the cluster of the customer. For example, Time_Day, Average Click Duration, etc.
#
# 2)  Most of your selected variables will be numerical (continuous or discrete), then categorize them into four categories.
#
# 3)  With the selected variables, perform pivot tables. On the horizontal axis, you will have the clusters, and on the vertical axis, you will have the categories of each variable. Notice that you have to do one pivot table per variable.
#
# 4)  Calculate the percentage by column for each pivot table. The sum of each row (cluster) must be 100.
#
# 5)  Interpret the results for each pivot table.
#
# 6)  Use any known metrics to estimate clustering algorithm performance (how good are the clusters you found?). Comment on the results obtained.

# %% [markdown]
# ---
#
# **1)  Select 2-3 variables you think are relevant to identify the cluster of the customer. For example, Time_Day, Average Click Duration, etc.**
#
# ---

# %%
# TODO

# %% [markdown]
# ---
#
# **2)  Most of your selected variables will be numerical (continuous or discrete), then categorize them into four categories.**
#
# ---

# %%
# TODO

# %% [markdown]
# ---
#
# **3)  With the selected variables, perform pivot tables. On the horizontal axis, you will have the clusters, and on the vertical axis, you will have the categories of each variable. Notice that you have to do one pivot table per variable.**
#
# ---

# %%
# TODO

# %% [markdown]
# ---
#
# **4)  Calculate the percentage by column for each pivot table. The sum of each row (cluster) must be 100.**
#
# ---

# %%
# TODO

# %% [markdown]
# ---
#
# **5)  Interpret the results for each pivot table.**
#
# ---

# %%
# TODO

# %% [markdown]
# ---
#
# **6)  Use any known metrics to estimate clustering algorithm performance (how good are the clusters you found?). Comment on the results obtained.**
#
# ---

# %%
# TODO

# %% [markdown]
# ## 3. Bonus Question

# %% [markdown]
# We remind you that we consider and grade the bonuses only if you complete the entire assignment.
#
# [Density-based clustering](https://wires.onlinelibrary.wiley.com/doi/epdf/10.1002/widm.30) identifies clusters as regions in the data space with high point density that are separated from other clusters by regions of low point density. The data points in the separating regions of low point density are typically considered noise or outliers. Typical algorithms that fall into this category are [OPTICS](https://dl.acm.org/doi/pdf/10.1145/304181.304187) and [DBSCAN](https://cdn.aaai.org/KDD/1996/KDD96-037.pdf).
#
# 1)  Ask ChatGPT (or any other LLM tool) to list three algorithms for Density-Based Clustering. Choose one and use it on the same dataset you used in 2.3. Analyze your results: how different are they from the centroid-based version?
#
# __Note__: You can implement your algorithm from scratch or use the one implemented in the scikit-learn library; the choice is up to you!

# %% [markdown]
# ---
#
# **answer from chatGPT**:
#
# 1) **DBSCAN (Density-Based Spatial Clustering of Applications with Noise)**: <br>
# DBSCAN is a popular density-based clustering algorithm that groups together data points that are close to each other and have a sufficient number of neighboring points within a specified radius. It is effective in discovering clusters of arbitrary shapes and is robust to noise.
# 2) **OPTICS (Ordering Points To Identify the Clustering Structure)**: <br>
# OPTICS is another density-based clustering algorithm that extends the ideas of DBSCAN. It introduces the concept of reachability distance, which provides a more flexible approach to capturing clusters of varying densities. OPTICS produces a reachability plot, allowing users to explore different cluster hierarchies.
# 3) **HDBSCAN (Hierarchical Density-Based Spatial Clustering of Applications with Noise)**: <br>
# HDBSCAN is an extension of DBSCAN that incorporates a hierarchical approach to density-based clustering. It can automatically determine the number of clusters and identify outliers. HDBSCAN produces a tree of clusters, allowing users to explore different levels of granularity in the clustering structure.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import OPTICS
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from operator import itemgetter

#USE DBSCAN
#import the dataset
pca_df = pd.read_csv('pca_df.csv')
pca_df_sample = pca_df.sample(10000)

# %%
from mpl_toolkits.mplot3d import Axes3D

scaler = StandardScaler()
pca = PCA(n_components=3)  # Change to 3 components for 3D plotting

# Scale and transform the data using PCA
pca_data = scaler.fit_transform(pca_df_sample)
pca_data = pca.fit_transform(pca_data)

# Apply the OPTICS algorithm on the PCA dataset
optics = OPTICS(min_samples=5, xi=0.05, min_cluster_size=0.05)
optics.fit(pca_data)

# Generate a unique name for the 'Cluster' column
cluster_column_name = 'Cluster'
counter = 1
while cluster_column_name in pca_df_sample.columns:
    cluster_column_name = f'Cluster_{counter}'
    counter += 1

# Add the Cluster column to the dataset
pca_df_sample.insert(0, cluster_column_name, optics.labels_)

# Plot the results in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

unique_labels = set(optics.labels_)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        col = [0, 0, 0, 1]  # Noise points are black

    class_member_mask = (optics.labels_ == k)
    xy = pca_data[class_member_mask]
    ax.scatter(xy[:, 0], xy[:, 1], xy[:, 2], c=[col], edgecolors='k', s=50, label=f'Cluster {k}')

ax.set_title('OPTICS Clustering (3D)')
ax.set_xlabel('PCA Dimension 1')
ax.set_ylabel('PCA Dimension 2')
ax.set_zlabel('PCA Dimension 3')
ax.legend()
plt.show()

# %% [markdown]
# ## 4. Command Line Question

# %% [markdown]
# Here is another command line question to enjoy. We previously stated that using the command line tools is a skill that Data Scientists must master.
#
# In this question, you should use any command line tool that you know to answer the following questions using the same dataset that you have been using so far:
#   + What is the most-watched Netflix title?
#   + Report the average time between subsequent clicks on Netflix.com
#   + Provide the ID of the user that has spent the most time on Netflix
#
# __Important note:__ You may work on this question in any environment (AWS, your PC command line, Jupyter notebook, etc.), but the final script must be placed in CommandLine.sh, which must be executable. Please run the script and include a __screenshot__ of the <ins>output</ins> in the notebook for evaluation.

# %% [markdown]
# ---
#
# In this exercise, we were asked to answer the following questions using only command line tools:
#
# - **Q1) What is the most-watched Netflix title?**
#
#     To answer this question, we counted the number of occurrences of each title and returned the one with the highest frequency. We chose not to consider the actual time spent watching each title as a comparison parameter because we believed that this criterion could have skewed the result due to the heterogeneity of the durations of the various films.
#
# - **Q2) Report the average time between subsequent clicks on Netflix.com**
#
#     To answer this question, we first sorted the dataset chronologically by clicks, ordering the `datetime` column in ascending order. Subsequently, we calculated the time elapsed between one click and the next one, and finally we took the average of these differences.
#
# - **Q3) Provide the ID of the user that has spent the most time on Netflix**
#
#     To address this question, we first grouped the rows of the dataset for each individual user identified through the `user_id` column. Then, we obtained the total time spent on Netflix cumulating the `duration` column for each user. Finally, we returned the ID with the maximum value of this sum.
#
#
# The results of these queries are displayed in the screenshot below, while the code used can be found in the `CommandLine.sh` file in the repository. The file contains comprehensive comments explaining its functionality. Of course, the file is executable, and the results are reproducible if the following steps are followed:
#
# 1. The `CommandLine.sh` file and the dataset need to be placed in the same folder;
#
# 2. You must navigate to the folder containing the two files using the terminal;
#
# 3. You need to enable the execution permissions for the file by running the following code $\to$ `chmod +x CommandLine.sh`
#
# 4. Finally, you can execute the file using the following command $\to$ `./CommandLine.sh`
#
# **ATTENTION**
#
# This bash script utilizes the `mktime` function, which is not natively present in the `awk` command of the macOS operating systems. Therefore, to make the file executable, it is necessary to install the `gawk` command, which is an extended and enhanced version of the previous command. To do so, you need to use a package manager for macOS, such as `Homebrew`, which can be installed by running the following command in the terminal:
#
# `/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"`
#
# This command can also be directly copied from the Homebrew website, which can be accessed through this [link](https://brew.sh/).
#
# Once this is done, you can install the gawk command by executing the following command in the terminal:
#
# `brew install gawk`
#
# This command and function should already be natively supported by the Windows operating system so, on such devices, no additional measures are required beyond those already outlined in points 1-2-3-4.
#
# ---
#
#
# ![CLQ-Screenshot.png](attachment:CLQ-Screenshot.png)

# %% [markdown]
# ## 5. Algorithmic Question

# %% [markdown]
# Federico studies in a demanding university where he has to take a certain number $N$ of exams to graduate,  but he is free to choose in which order he will take these exams. Federico is panicking since this university is not only one of the toughest in the world but also one of the weirdest. His final grade won't depend at all on the mark he gets in these courses: there's a precise evaluation system.
#
# He was given an initial personal score of $S$ when he enrolled, which changes every time he takes an exam: now comes the crazy part.
# He soon discovered that every of the $N$ exams he has to take is assigned a mark $p$. Once he has chosen an exam, his score becomes equal to the mark $p$, and at the same time, the scoring system changes:
# + If he takes an "easy" exam (the score of the exam being less than his score), every other exam's mark is increased by the quantity $S - p$.
# + If he takes a "hard" exam (the score of the exam is greater than his score), every other exam's mark is decreased by the quantity $p - S$.
#
# So, for example, consider $S=8$ as the initial personal score. Federico must decide which exam he wants to take, being $[5,7,1]$ the marks list. If he takes the first one, being $5 < 8$ and $8 - 5 = 3$, the remaining list now becomes $[10,4]$, and his score is updated as $S = 5$.
#
# In this chaotic university where the only real exam seems to be choosing the best way to take exams, you are the poor student advisor who is facing a long queue of confused people who need some help. Federico is next in line,  and he comes up in turn with an inescapable question: he wants to know which is the highest score possible he could get.
#
# a) Fortunately, you have a computer app designed by a brilliant student. Federico wants you to show him the code which this app is based on
# because he wants to do paid counseling for other desperate students: in a *recursive* fashion, the helped helps the helpable.
#
# b) Federico is getting angry because he claims that your code is slow! Show him formally with a big-O notation that he is as crazy as this university!
#
# c) If, unfortunately, Federico is right in the grip of madness, he will threaten you to optimize the code through a different approach.
# You should end this theater of the absurd by any means! (And again, formally prove that you improved time complexity)
#
# d) Ask chatGPT for a third (optimized) implementation and analyze again its time complexity. Be careful (and crafty) in defining the prompt, and challenge the machine in this coding question!
#
# Here are some input/output examples (the first value is the initial personal score, and the second line contains the list of marks):
#
# __Input 1__
# ```
# 8
# 5 7 1
# ```
#
# __Output 1__
# ```
# 11
# ```
#
# __Input 2__
# ```
# 25
# 18 24 21 32 27
# ```
#
# __Output 2__
# ```
# 44
# ```
#
# __Input 3__
# ```
# 30
# 13 27 41 59 28 33 39 19 52 48 55 79
# ```
#
# __Output 3__
# ```
# 205
# ```

# %% [markdown]
# **a) Fortunately, you have a computer app designed by a brilliant student. Federico wants you to show him the code which this app is based on
# because he wants to do paid counseling for other desperate students: in a *recursive* fashion, the helped helps the helpable.**

# %% [markdown]
# ---
#
# The text of this first request seems to require we us to implement an algorithm that solves the problem using recursion. However, given the nature of the problem and the extensive number of possible permutations this approach is expected to be very inefficient in terms of computational time. While a "brute-force" approach would iterate trough every possible permutation without exploiting the fact that computations will be identical util a element of the permutation differ we decided to implement a smarter dynamic programming approach; this remembers previous computations, saving a noticeable amount of computational time.
#
# ---

# %%
def iterative_call(student_score, marks_list, solved_subproblems = {}):
    # base case, if the marks list has only one element we are forced to take it
    if len(marks_list) == 1:
        return marks_list[0]
    
    # if we have already solved this scenario we can take the result without
    # computing it again another time
    elif (student_score, marks_list) in solved_subproblems:
        return solved_subproblems[(student_score, marks_list)]
    
    # otherwise is a new scenario, we have to compute it by checking every possible path
    else:
        # we create a list of tuples, each tuple is the mark list if we chose to take a certain mark
        new_marks_lists = [tuple(mark + (student_score - marks_list[i]) for mark in marks_list[:i] + marks_list[i+1:]) for i in range(len(marks_list))]

        # we create a list of scores, that are the output of each new subproblem
        new_scores = [iterative_call(marks_list[i], new_marks_lists[i], solved_subproblems) for i in range(len(marks_list))]

        # we get the mark among all subproblems
        best_score = max(new_scores)
        
        # update solved subproblems dictionary
        solved_subproblems[(student_score, marks_list)] = best_score

        return best_score

def algorithmic_question_v1(input_string):
    input_list = input_string.split("\n")

    # get student score from input string
    original_student_score = int(input_list[0])

    # get marks list from input string
    original_marks_list = tuple(map(int, input_list[1].split(" ")))

    best_score = iterative_call(original_student_score, original_marks_list)

    print(best_score)

# tests as given by the text of the homework

input1 = "8\n5 7 1"
print("Test1:")
algorithmic_question_v1(input1)

input2 = "26\n18 24 21 32 27"
print("Test2:")
algorithmic_question_v1(input2)

input3 = "30\n13 27 41 59 28 33 39 19 52 48 55 79"
print("Test3:")
algorithmic_question_v1(input3)
# Out:
# Test1:
# 11
# Test2:
# 44
# Test3:
# 205

# %% [markdown]
# **b) Federico is getting angry because he claims that your code is slow! Show him formally with a big-O notation that he is as crazy as this university!**
#
# ---
#
# **Time complexity:**
#
# We will analyze the computational time of this first algorithm in Big-O notation in the `average case scenario` to exploit the constant time get item cost of python dictionaries.
#
# The algorithm explores all possible permutations of marks choices using recurive calls to avoid having to calculate again already seen scenarios. The iterative call functions is used `n` times in the first level of recursion and each of those calls lead to other `n - 1` calls in the second level of recursion and so on...
#
# $n + n * (n - 1) + n * (n - 1) * (n - 2) + ... + n! = n! * \sum_{k = 1}^{n - 1} \frac{1}{k!} \in O(n!)$
#
# The number of permutations is factorial and the number of iterative call is even higher, but in the same order. This means that even if our iterative call operation would have a constant time cost our algorithm would have a computational time of `O(n!)`. We now have to find the time complexity of a single execution of `iterative_call`. We will say that the current marks list has length `i`.
#
# This function is composed of a condition that checks the length of the array (constant time), another condition that check if the scenario have already been seen (constant time thanks to our `average case scenario` assumption) and a cycle trough the current elements of marks list (`i` repetitions) that for every cycle create a new array (linear cost `O(i)`), an update operation on the new array (linear cost `O(i)`), the next iterative call (that will have length `i - 1`) and a max operation (constant time).
#
# We can see that the value of `i` in the iterative call is not significative in the result of our analysis, as for the extreme case where `i = constant` the total cost of the algorithm will be:
#
# $n! * constant \in O(n!)$
#
# And in the opposite extreme where `i = n` the total cost will be:
#
# $n! * n < n! * (n + 1) = (n + 1)! \in O((n + 1)!) = O(n!)$
#
# The cost of the algorithm is therefore factorial, `O(n!)`. Such cost is unfeasable in real scenarios. By Stirling's approximation we can have a cleared idea of how bad a factorial computational cost is:
#
# $n! \approx \sqrt{2\pi n}\left(\frac{n}{e}\right)^n$
#
# That is `O(n^n)`. The examples executed above are small enough to be computed in a few seconds, but even only doubling the size of the input of test3 (that means input = $12 * 2 = 24$) shows a great slowdown as even half an hour hasn't been enough to complete the computation.
#
# ---

# %% [markdown]
# **c) If, unfortunately, Federico is right in the grip of madness, he will threaten you to optimize the code through a different approach.
# You should end this theater of the absurd by any means! (And again, formally prove that you improved time complexity)**
#
# ---
#
# This new algorithm is based on the following observations on every permutation of the marks that yields the best output:
#
# * They are an alternation of values below and above the median. The order in which we take those values is not significant, the only thing that matters is the alternation between above and below the median.
# * They start with a value below the median and end with one above.
# * The only time there are two successive elements are from the same side is when the number of marks is uneven.
#
# Furthermore, we can split a permutation with this properties into couples and observe that every couple push the value of every mark in the list forward by a factor equal to the difference between the two values. There is also a "starting value" that is the median itself when the number of marks is uneven and the starting score of the student when the number of marks is even (this means that the starting value of the student is not significative if the number of marks is odd). Since as we said before the order is not significant we can take them in any order and see the final results as the sum of all the values above the median minus all the values below.
#
# Therefore to find the highest output value without visiting and executing all the permutations we can think of an algorithm that does the following: finds the median, divide the marks list in two sets, one less or equal the median and the other greater than the median. Once splitted into two groups we can just sum all the values above the median and subtract the values below.
#
# ---

# %%
def algorithmic_question_v2(input_string):
    input_list = input_string.split("\n")

    # get student score from input string
    student_score = int(input_list[0])

    # get marks list from input string
    marks_list = list(map(int, input_list[1].split(" ")))

    # sort values
    marks_list.sort()

    # treat even/odd case
    result = 0 if len(marks_list) % 2 == 1 else student_score

    # sum value above median and substract values below median
    result += sum(marks_list[len(marks_list) // 2 :]) - sum(marks_list[: len(marks_list) // 2])
    
    print(result)

# tests as given by the text of the homework

input1 = "8\n5 7 1"
print("Test1:")
algorithmic_question_v2(input1)

input2 = "25\n18 24 21 32 27"
print("Test2:")
algorithmic_question_v2(input2)

input3 = "30\n13 27 41 59 28 33 39 19 52 48 55 79"
print("Test3:")
algorithmic_question_v2(input3);
# Out:
# Test1:
# 11
# Test2:
# 44
# Test3:
# 205

# %% [markdown]
# ---
#
# **Time complexity:**
#
# We will analyze the computational time of the algorithm in Big-O notation in the `worst case scenario`.
#
# We can see the algorithm as divided in three principal components with their cost proportional to the size number of marks in the input, that we will call `n`.
#
# * The first thing the algorithm does is read all the input, for which it takes time proportional to the size of the input, `O(n)`.
# * After reading all the input the marks list is sorted to find the median. Using any of the worst case scenario optimal sorting algorithm will take us `O(n * logn)` time.
# * Finally we have to sum and substract every value of the mark list according to its position in the sorted list. Since the sum/substraction operation is constant and its executed exactly once for every element in the marks list this component of the algorithm has linear cost `O(n)`.
#
# The cost of the algorithm in the worst case scenario is therefore `O(n * logn)` as the sorting operation is the heaviest component of the algorithm. We can observe that the results can be even better if re-design our algorithm focussing on performances for the `average case scenario`:
#
# Since we do not really need the sorting of the list but only to find the median and divide between above and below it we can execute a `quickselect` algorithm instead of a sorting and then divide into two sets by confronting each element with the median. The quickselect, as well as the subsequent division in subsets has a average computational time of `O(n)`, rendering the algorithm with linear cost `O(n)` in the average case scenario.
#
# We decided to not use this design in our algorithm as the worst case scenario for it is given by the worst case of quickselect and is `O(n^2)`.
#
# ---

# %% [markdown]
# **d) Ask chatGPT for a third (optimized) implementation and analyze again its time complexity. Be careful (and crafty) in defining the prompt, and challenge the machine in this coding question!**

# %% [markdown]
# ---
#
# We asked Chat GPT 3.5 to write an algorithm using the following prompt:
#
# ```
# Resolve the problem proposed by the following text with a python algorithm, giving particular attention to code correctness and to find a strategy that minize its computational cost:
# [The proposed algorithm text, including the examples]
# ```
#
# And the received output is:
#
# ```
# This problem can be approached through a recursive algorithm that explores all possibilities. Here's a Python solution that implements this approach:
#
# def highest_score_possible(score, marks):
#     if not marks:  # Base case: if there are no exams left, return the current score
#         return score
#
#     max_score = score  # Initialize the maximum score with the current score
#
#     for i in range(len(marks)):
#         new_score = marks[i]  # Set new score if Federico takes this exam
#
#         # Determine the new list of marks based on the exam chosen
#         new_marks = marks[:i] + marks[i+1:]
#         for j in range(len(new_marks)):
#             if new_score > score:  # For hard exams
#                 new_marks[j] -= new_score - score
#             elif new_score < score:  # For easy exams
#                 new_marks[j] += score - new_score
#
#         # Recursive call to find the maximum score
#         max_score = max(max_score, highest_score_possible(new_score, new_marks))
#
#     return max_score
#
# # Example usage
# initial_score = 8
# marks_list = [5, 7, 1]
# result = highest_score_possible(initial_score, marks_list)
# print(result)
#
#
# This algorithm works through recursion, exploring every possible choice Federico can make at each step (taking a different exam) and calculating the maximum score achievable.
#
# However, the code can become inefficient for larger inputs due to its recursive nature. The time complexity of this solution is exponential, specifically O(2^N), where N is the number of exams Federico has to take. As the number of exams increases, the number of recursive calls and computations grows exponentially, making it slow for larger inputs.
#
# To optimize this algorithm, we can utilize dynamic programming to store intermediate results and avoid redundant calculations. This can significantly improve the efficiency of the solution by reducing unnecessary recursive calls.
#
# Let me know if you'd like to explore this optimization further!
# ```
#
# This result is particularly bad, as it's wrong in the results and tries to mimick a recursive resolution of the problem, that as we have seen has a very bad computational time. However the LLM fails to grasp the resolution algorithm itself, as it consider the current student score of an intermediate operation as a possible value for the output. We point that out to the LLM:
#
# ```
# Don't initialize the maximum with the current score
# ```
#
# And the response is:
#
# ```
# You're right! We don't need to initialize the maximum score with the current score. Here's an updated version of the code:
#
# def highest_score_possible(score, marks):
#     if not marks:  # Base case: if there are no exams left, return the current score
#         return score
#
#     max_score = float('-inf')  # Initialize maximum score as negative infinity
#
#     for i in range(len(marks)):
#         new_score = marks[i]  # Set new score if Federico takes this exam
#
#         # Determine the new list of marks based on the exam chosen
#         new_marks = marks[:i] + marks[i+1:]
#         for j in range(len(new_marks)):
#             if new_score > score:  # For hard exams
#                 new_marks[j] -= new_score - score
#             elif new_score < score:  # For easy exams
#                 new_marks[j] += score - new_score
#
#         # Recursive call to find the maximum score
#         max_score = max(max_score, highest_score_possible(new_score, new_marks))
#
#     return max_score
#
# # Example usage
# initial_score = 8
# marks_list = [5, 7, 1]
# result = highest_score_possible(initial_score, marks_list)
# print(result)
#
# This change avoids initializing max_score with the current score and uses float('-inf') to ensure the correct initialization of the maximum score.
# ```
#
# Now the algorithm is correct, but the solution is brute-force and doesn't uses a dynamic-programming approach, increasing further the computational time of the algorithm, that would however still be in the big O notation of 'O(n!)' as it explores all possible iterative calls are 'O(n!)' in number and 'O(n)' in cost. Since the request asked us to study an optimized implementation made by chatGPT we try to obtain it by explaining our observations to the LLM:
#
# ```
# Create an optimized version of this algorithm by exploiting those observations made on the optimal results:
# [Paragraph on the observations written in point c of this exercise]
# ```
#
# And the received output is:
#
# ```
# Absolutely, leveraging these observations allows for a more direct and optimized approach. We can use the median to split the marks into two sets: one with marks above the median and another with marks below or equal to the median. Then, we can perform calculations on these sets to determine the highest possible score Federico can achieve.
#
# Here's an implementation based on this approach:
#
# def highest_score_possible_optimized(score, marks):
#     marks.sort()  # Sort the marks
#     median_index = len(marks) // 2
#     median = marks[median_index] if len(marks) % 2 != 0 else (marks[median_index - 1] + marks[median_index]) // 2
#
#     marks_below_median = marks[:median_index]
#     marks_above_median = marks[median_index + (1 if len(marks) % 2 != 0 else 0):]
#
#     # Sum all values above the median and subtract the values below
#     return sum(marks_above_median) - sum(marks_below_median)
#
# # Example usage
# initial_score = 8
# marks_list = [5, 7, 1]
# result = highest_score_possible_optimized(initial_score, marks_list)
# print(result)
#
# This optimized version sorts the marks, identifies the median, and then splits the marks into two sets: one with values above the median and another with values below or equal to the median. Finally, it calculates the highest possible score by summing the values above the median and subtracting the values below or equal to the median. This approach doesn't require exploring all permutations and directly computes the highest achievable score based on the properties observed.
# ```
#
# While the algorithm is not entirely correct as it does not take into account the starting value of the student and we could challenge chatGPT further to adjust it, the computational cost is the same as it would be for the correct solution and is the same as what we have described above, given that chatGPT just transposed our observations into code.
#
# ---
